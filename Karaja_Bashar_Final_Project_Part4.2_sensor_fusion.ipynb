# %% [markdown]
# ## Part 4.2: Explore multi-sensor and multi-modality sensor fusion with deep learning
#
# Previously in part4.1, we realized we were actually using only a very small portion of the PAMAP2 dataset. And now we have selected more sensors and modalities. We can use the sensor fusion knowledge we've learned in class

# %%
#import the packages that we need
import numpy as np
import matplotlib.pyplot as plt
import sklearn as skl
import itertools
from sklearn import neighbors, metrics
from sklearn.model_selection import KFold, train_test_split
from sklearn.model_selection import cross_validate
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Import files from drive
from google.colab import drive
drive.mount('/content/drive')
# this might prompt you to authorize and might take a minute
# !cp -r "/content/drive/My Drive/PAMAP2_Dataset/WindowSamples" .
# Out:
# Mounted at /content/drive

# %%
def loadXy(ID):
  # Default file names
  fileName = 'WindowSamples/subject10'+str(ID)+'_multi.npz'
  # Load data from numpy file
  data = np.load(fileName)
  # first lets see what's in the file
  #for k in data.iterkeys():
  #  print(k)
  # Skip the first column because it's timestamp
  X = data['arr_0'][:,:,1:]
  y = data['arr_1']
  return X, y

def balance_data(X, y):
  X_balanced = np.zeros((0, X.shape[1], X.shape[2])) #note we've changed from X_features to X for simplicity
  y_balanced = np.zeros((0))
  #first let's count how many samples are in each class.
  numClass = len(np.unique(y))
  m_counts = np.zeros((numClass))
  m_labels = np.unique(y)
  for i in range(0, numClass):
    m_counts[i] = int(sum(y==m_labels[i]))
  m_least = int(m_counts.min())
  for i in range(1, numClass): # note we are jumping over class 0 now
    rand_ind = np.random.permutation(int(m_counts[i]))
    m_subind = np.where(y==m_labels[i]) # this is the sub-index of the current class in the whole data file
    m_subind_balanced = m_subind[0][rand_ind[0:m_least]]
    # add the selected samples from the current class to the overall balanced dataset
    X_balanced = np.concatenate( (X_balanced, X[m_subind_balanced,:,:]) )
    y_balanced = np.concatenate( (y_balanced, y[m_subind_balanced]) )
  return X_balanced, y_balanced

def plot_confusion_matrix(cm, class_names):
  """
  You can mostly ignore this function
  Returns a matplotlib figure containing the plotted confusion matrix.
  Args:
  cm (array, shape = [n, n]): a confusion matrix of integer classes
  class_names (array, shape = [n]): String names of the integer classes
  """
  figure = plt.figure(figsize=(len(class_names)/2, len(class_names)/2))
  plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
  acc = np.sum( cm * np.eye(len(class_names)) ) / np.sum(cm)

  plt.title("CM , acc:"+str(round(acc,4)))
  plt.colorbar()
  tick_marks = np.arange(len(class_names))
  plt.xticks(tick_marks, class_names, rotation=45)
  plt.yticks(tick_marks, class_names)

  # Normalize the confusion matrix.
  cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

  # Use white text if squares are dark; otherwise black.
  threshold = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      color = "white" if cm[i, j] > threshold else "black"
      plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

  #plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  #plt.show()
  return figure

def label2categorical(m_labels, numClass):
  m_labels_exp = np.zeros( ( len(m_labels), numClass ) )
  LUT = np.unique(m_labels) # to handel sporadically distributed labels
  for i in range (0, len(m_labels)):
      m_labels_exp[i, np.where(LUT==int(m_labels[i]))] = 1
  return m_labels_exp

# %%
X, y = loadXy(1)
X_test, y_test = balance_data(X, y)

print(X_test.shape)
print(y_test.shape)

# Check the activites performed by the subject
print(np.unique(y_test))
numClass = len(np.unique(y_test))
# Out:
# (3048, 200, 18)
# (3048,)
# [ 1.  2.  3.  4.  5.  6.  7. 12. 13. 16. 17. 24.]

# %%
# then we prepare the training data with persons 2-8
X_train = np.zeros((0,200,18)) # (sample, time, channel)
y_train = np.zeros((0))
for ID in range(2,8):
  print('ID: '+str(ID))
  X, y = loadXy(ID)
  X, y = balance_data(X,y)
  X_train = np.concatenate( (X_train, X) )
  y_train = np.concatenate( (y_train, y) )

print(X_train.shape)
print(y_train.shape)

# Check the activites performed by the subjects
print(np.unique(y_train))
numClass = len(np.unique(y_train))
# Out:
# ID: 2
# ID: 3
# ID: 4
# ID: 5
# ID: 6
# ID: 7
# (9093, 200, 18)
# (9093,)
# [ 1.  2.  3.  4.  5.  6.  7. 12. 13. 16. 17. 24.]

# %% [markdown]
# **Now let's define a Early Fusion model**

# %%
m_input = layers.Input(shape=(200,18))
m_output = layers.Conv1D(filters = 20, kernel_size = (3), padding='same', activation='relu')(m_input)
m_output = layers.MaxPooling1D(pool_size=(3))(m_output)
m_output = layers.BatchNormalization()(m_output)
m_output = layers.Dropout(0.2)(m_output)
m_output = layers.Conv1D( filters = 40, kernel_size = (3), padding='same', activation='relu')(m_output)
m_output = layers.BatchNormalization()(m_output)
m_output = layers.MaxPooling1D(pool_size=(3))(m_output)
m_output = layers.Dropout(0.2)(m_output)
m_output = layers.Conv1D( filters = 80, kernel_size = (3), padding='same', activation='relu')(m_output)
m_output = layers.BatchNormalization()(m_output)
m_output = layers.Dropout(0.2)(m_output)
m_output = layers.Conv1D( filters = 1, kernel_size = (3), padding='same', activation='relu')(m_output)
m_output = layers.Flatten()(m_output)
m_output = layers.Dense(20, activation='relu')(m_output)
m_output = layers.Dropout(0.2)(m_output)
m_output = layers.Dense(numClass, activation='softmax')(m_output)

model_EF = keras.models.Model(inputs = m_input, outputs = m_output)

# optimizer
m_opt = keras.optimizers.Adam()
model_EF.compile(optimizer=m_opt,
                      loss=keras.losses.BinaryCrossentropy(),
                      metrics=['accuracy'])
model_EF.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 200, 18)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ (None, 200, 20)             │           1,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 66, 20)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 66, 20)              │              80 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 66, 20)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 66, 40)              │           2,440 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 66, 40)              │             160 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 22, 40)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 22, 40)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_2 (Conv1D)                    │ (None, 22, 80)              │           9,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 22, 80)              │             320 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 22, 80)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_3 (Conv1D)                    │ (None, 22, 1)               │             241 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 22)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 20)                  │             460 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 20)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 12)                  │             252 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,733 (57.55 KB)
#  Trainable params: 14,453 (56.46 KB)
#  Non-trainable params: 280 (1.09 KB)

# %%
# early stopping training code block
epoch = 10000  # now with the patience and early stopping, we can define a abundantly big training epoch
batch = 200

cb_checkpoint = tf.keras.callbacks.ModelCheckpoint('bestmodel.h5', monitor='val_accuracy', mode='max',
                                                   verbose=1,save_weights_only=False,save_best_only=True)
cb_earlystop = tf.keras.callbacks.EarlyStopping(patience=20,monitor='val_accuracy',mode='max',
                                                verbose=1,restore_best_weights=True)

numClass = 12
history = model_EF.fit( x = X_train, y = label2categorical(y_train, numClass), epochs = epoch, batch_size=batch,
                       validation_split=0.2, verbose = 2,
                       callbacks=[cb_checkpoint, cb_earlystop]
        )
# Out:
# Epoch 1/10000
#
# Epoch 1: val_accuracy improved from -inf to 0.08301, saving model to bestmodel.h5
# 37/37 - 6s - loss: 0.6263 - accuracy: 0.0850 - val_loss: 0.6654 - val_accuracy: 0.0830 - 6s/epoch - 151ms/step
# Epoch 2/10000
#
# Epoch 2: val_accuracy improved from 0.08301 to 0.15778, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.4288 - accuracy: 0.1030 - val_loss: 0.4675 - val_accuracy: 0.1578 - 3s/epoch - 84ms/step
# Epoch 3/10000
#
# Epoch 3: val_accuracy did not improve from 0.15778
# 37/37 - 4s - loss: 0.3432 - accuracy: 0.1230 - val_loss: 0.3483 - val_accuracy: 0.0990 - 4s/epoch - 115ms/step
# Epoch 4/10000
#
# Epoch 4: val_accuracy did not improve from 0.15778
# 37/37 - 3s - loss: 0.3111 - accuracy: 0.1406 - val_loss: 0.3250 - val_accuracy: 0.0929 - 3s/epoch - 86ms/step
# Epoch 5/10000
#
# Epoch 5: val_accuracy did not improve from 0.15778
# 37/37 - 3s - loss: 0.2946 - accuracy: 0.1607 - val_loss: 0.3115 - val_accuracy: 0.0825 - 3s/epoch - 84ms/step
# Epoch 6/10000
#
# Epoch 6: val_accuracy did not improve from 0.15778
# 37/37 - 3s - loss: 0.2827 - accuracy: 0.1954 - val_loss: 0.3007 - val_accuracy: 0.1165 - 3s/epoch - 83ms/step
# Epoch 7/10000
#
# Epoch 7: val_accuracy did not improve from 0.15778
# 37/37 - 3s - loss: 0.2737 - accuracy: 0.2042 - val_loss: 0.2922 - val_accuracy: 0.1100 - 3s/epoch - 83ms/step
# Epoch 8/10000
#
# Epoch 8: val_accuracy did not improve from 0.15778
# 37/37 - 3s - loss: 0.2655 - accuracy: 0.2307 - val_loss: 0.2849 - val_accuracy: 0.1303 - 3s/epoch - 83ms/step
# Epoch 9/10000
#
# Epoch 9: val_accuracy improved from 0.15778 to 0.17427, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.2555 - accuracy: 0.2609 - val_loss: 0.2761 - val_accuracy: 0.1743 - 3s/epoch - 86ms/step
# Epoch 10/10000
#
# Epoch 10: val_accuracy improved from 0.17427 to 0.18527, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.2448 - accuracy: 0.3130 - val_loss: 0.2684 - val_accuracy: 0.1853 - 3s/epoch - 88ms/step
# Epoch 11/10000
#
# Epoch 11: val_accuracy improved from 0.18527 to 0.19791, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.2365 - accuracy: 0.3529 - val_loss: 0.2597 - val_accuracy: 0.1979 - 3s/epoch - 86ms/step
# Epoch 12/10000
#
# Epoch 12: val_accuracy improved from 0.19791 to 0.20451, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.2248 - accuracy: 0.3873 - val_loss: 0.2522 - val_accuracy: 0.2045 - 3s/epoch - 85ms/step
# Epoch 13/10000
#
# Epoch 13: val_accuracy improved from 0.20451 to 0.23364, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.2163 - accuracy: 0.4024 - val_loss: 0.2425 - val_accuracy: 0.2336 - 3s/epoch - 86ms/step
# Epoch 14/10000
#
# Epoch 14: val_accuracy improved from 0.23364 to 0.23694, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.2071 - accuracy: 0.4362 - val_loss: 0.2360 - val_accuracy: 0.2369 - 3s/epoch - 87ms/step
# Epoch 15/10000
#
# Epoch 15: val_accuracy improved from 0.23694 to 0.28422, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1992 - accuracy: 0.4552 - val_loss: 0.2306 - val_accuracy: 0.2842 - 3s/epoch - 84ms/step
# Epoch 16/10000
#
# Epoch 16: val_accuracy did not improve from 0.28422
# 37/37 - 4s - loss: 0.1931 - accuracy: 0.4770 - val_loss: 0.2326 - val_accuracy: 0.2694 - 4s/epoch - 100ms/step
# Epoch 17/10000
#
# Epoch 17: val_accuracy did not improve from 0.28422
# 37/37 - 3s - loss: 0.1866 - accuracy: 0.4953 - val_loss: 0.2281 - val_accuracy: 0.2672 - 3s/epoch - 83ms/step
# Epoch 18/10000
#
# Epoch 18: val_accuracy did not improve from 0.28422
# 37/37 - 3s - loss: 0.1821 - accuracy: 0.5133 - val_loss: 0.2298 - val_accuracy: 0.2556 - 3s/epoch - 83ms/step
# Epoch 19/10000
#
# Epoch 19: val_accuracy did not improve from 0.28422
# 37/37 - 3s - loss: 0.1774 - accuracy: 0.5231 - val_loss: 0.2252 - val_accuracy: 0.2787 - 3s/epoch - 82ms/step
# Epoch 20/10000
#
# Epoch 20: val_accuracy improved from 0.28422 to 0.29577, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1714 - accuracy: 0.5393 - val_loss: 0.2196 - val_accuracy: 0.2958 - 3s/epoch - 87ms/step
# Epoch 21/10000
#
# Epoch 21: val_accuracy improved from 0.29577 to 0.32820, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1679 - accuracy: 0.5514 - val_loss: 0.2114 - val_accuracy: 0.3282 - 3s/epoch - 84ms/step
# Epoch 22/10000
#
# Epoch 22: val_accuracy did not improve from 0.32820
# 37/37 - 3s - loss: 0.1650 - accuracy: 0.5531 - val_loss: 0.2121 - val_accuracy: 0.3233 - 3s/epoch - 82ms/step
# Epoch 23/10000
#
# Epoch 23: val_accuracy improved from 0.32820 to 0.33810, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1622 - accuracy: 0.5660 - val_loss: 0.2134 - val_accuracy: 0.3381 - 3s/epoch - 84ms/step
# Epoch 24/10000
#
# Epoch 24: val_accuracy did not improve from 0.33810
# 37/37 - 3s - loss: 0.1586 - accuracy: 0.5815 - val_loss: 0.2161 - val_accuracy: 0.3315 - 3s/epoch - 83ms/step
# Epoch 25/10000
#
# Epoch 25: val_accuracy improved from 0.33810 to 0.38813, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1563 - accuracy: 0.5778 - val_loss: 0.2045 - val_accuracy: 0.3881 - 3s/epoch - 83ms/step
# Epoch 26/10000
#
# Epoch 26: val_accuracy improved from 0.38813 to 0.40132, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1510 - accuracy: 0.5972 - val_loss: 0.2019 - val_accuracy: 0.4013 - 3s/epoch - 85ms/step
# Epoch 27/10000
#
# Epoch 27: val_accuracy did not improve from 0.40132
# 37/37 - 3s - loss: 0.1472 - accuracy: 0.6127 - val_loss: 0.2088 - val_accuracy: 0.3815 - 3s/epoch - 82ms/step
# Epoch 28/10000
#
# Epoch 28: val_accuracy did not improve from 0.40132
# 37/37 - 3s - loss: 0.1446 - accuracy: 0.6133 - val_loss: 0.2049 - val_accuracy: 0.3958 - 3s/epoch - 82ms/step
# Epoch 29/10000
#
# Epoch 29: val_accuracy did not improve from 0.40132
# 37/37 - 3s - loss: 0.1425 - accuracy: 0.6346 - val_loss: 0.2064 - val_accuracy: 0.3722 - 3s/epoch - 82ms/step
# Epoch 30/10000
#
# Epoch 30: val_accuracy improved from 0.40132 to 0.42386, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1415 - accuracy: 0.6296 - val_loss: 0.2027 - val_accuracy: 0.4239 - 3s/epoch - 84ms/step
# Epoch 31/10000
#
# Epoch 31: val_accuracy improved from 0.42386 to 0.43375, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1380 - accuracy: 0.6402 - val_loss: 0.1984 - val_accuracy: 0.4338 - 3s/epoch - 83ms/step
# Epoch 32/10000
#
# Epoch 32: val_accuracy did not improve from 0.43375
# 37/37 - 3s - loss: 0.1367 - accuracy: 0.6486 - val_loss: 0.2018 - val_accuracy: 0.4057 - 3s/epoch - 80ms/step
# Epoch 33/10000
#
# Epoch 33: val_accuracy did not improve from 0.43375
# 37/37 - 3s - loss: 0.1351 - accuracy: 0.6534 - val_loss: 0.1991 - val_accuracy: 0.4277 - 3s/epoch - 81ms/step
# Epoch 34/10000
#
# Epoch 34: val_accuracy improved from 0.43375 to 0.46234, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1331 - accuracy: 0.6567 - val_loss: 0.1948 - val_accuracy: 0.4623 - 3s/epoch - 84ms/step
# Epoch 35/10000
#
# Epoch 35: val_accuracy improved from 0.46234 to 0.47993, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1319 - accuracy: 0.6548 - val_loss: 0.1938 - val_accuracy: 0.4799 - 3s/epoch - 83ms/step
# Epoch 36/10000
#
# Epoch 36: val_accuracy improved from 0.47993 to 0.48928, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1299 - accuracy: 0.6701 - val_loss: 0.1929 - val_accuracy: 0.4893 - 3s/epoch - 83ms/step
# Epoch 37/10000
#
# Epoch 37: val_accuracy improved from 0.48928 to 0.51182, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1278 - accuracy: 0.6727 - val_loss: 0.1812 - val_accuracy: 0.5118 - 3s/epoch - 84ms/step
# Epoch 38/10000
#
# Epoch 38: val_accuracy did not improve from 0.51182
# 37/37 - 3s - loss: 0.1284 - accuracy: 0.6703 - val_loss: 0.1888 - val_accuracy: 0.4799 - 3s/epoch - 81ms/step
# Epoch 39/10000
#
# Epoch 39: val_accuracy did not improve from 0.51182
# 37/37 - 3s - loss: 0.1247 - accuracy: 0.6822 - val_loss: 0.1850 - val_accuracy: 0.4728 - 3s/epoch - 82ms/step
# Epoch 40/10000
#
# Epoch 40: val_accuracy did not improve from 0.51182
# 37/37 - 3s - loss: 0.1236 - accuracy: 0.6849 - val_loss: 0.1883 - val_accuracy: 0.4920 - 3s/epoch - 82ms/step
# Epoch 41/10000
#
# Epoch 41: val_accuracy did not improve from 0.51182
# 37/37 - 3s - loss: 0.1219 - accuracy: 0.6959 - val_loss: 0.2040 - val_accuracy: 0.4354 - 3s/epoch - 81ms/step
# Epoch 42/10000
#
# Epoch 42: val_accuracy improved from 0.51182 to 0.55525, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1214 - accuracy: 0.7011 - val_loss: 0.1766 - val_accuracy: 0.5553 - 3s/epoch - 83ms/step
# Epoch 43/10000
#
# Epoch 43: val_accuracy did not improve from 0.55525
# 37/37 - 3s - loss: 0.1203 - accuracy: 0.7050 - val_loss: 0.2212 - val_accuracy: 0.4662 - 3s/epoch - 81ms/step
# Epoch 44/10000
#
# Epoch 44: val_accuracy did not improve from 0.55525
# 37/37 - 3s - loss: 0.1166 - accuracy: 0.7084 - val_loss: 0.2083 - val_accuracy: 0.4915 - 3s/epoch - 82ms/step
# Epoch 45/10000
#
# Epoch 45: val_accuracy did not improve from 0.55525
# 37/37 - 3s - loss: 0.1165 - accuracy: 0.7239 - val_loss: 0.1747 - val_accuracy: 0.5520 - 3s/epoch - 81ms/step
# Epoch 46/10000
#
# Epoch 46: val_accuracy did not improve from 0.55525
# 37/37 - 3s - loss: 0.1146 - accuracy: 0.7171 - val_loss: 0.1965 - val_accuracy: 0.5135 - 3s/epoch - 81ms/step
# Epoch 47/10000
#
# Epoch 47: val_accuracy did not improve from 0.55525
# 37/37 - 3s - loss: 0.1141 - accuracy: 0.7246 - val_loss: 0.2034 - val_accuracy: 0.5102 - 3s/epoch - 81ms/step
# Epoch 48/10000
#
# Epoch 48: val_accuracy did not improve from 0.55525
# 37/37 - 3s - loss: 0.1126 - accuracy: 0.7371 - val_loss: 0.1908 - val_accuracy: 0.5465 - 3s/epoch - 82ms/step
# Epoch 49/10000
#
# Epoch 49: val_accuracy did not improve from 0.55525
# 37/37 - 3s - loss: 0.1106 - accuracy: 0.7400 - val_loss: 0.1921 - val_accuracy: 0.5514 - 3s/epoch - 82ms/step
# Epoch 50/10000
#
# Epoch 50: val_accuracy improved from 0.55525 to 0.57944, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1093 - accuracy: 0.7462 - val_loss: 0.1859 - val_accuracy: 0.5794 - 3s/epoch - 82ms/step
# Epoch 51/10000
#
# Epoch 51: val_accuracy improved from 0.57944 to 0.61297, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.1088 - accuracy: 0.7492 - val_loss: 0.1737 - val_accuracy: 0.6130 - 3s/epoch - 84ms/step
# Epoch 52/10000
#
# Epoch 52: val_accuracy did not improve from 0.61297
# 37/37 - 3s - loss: 0.1078 - accuracy: 0.7532 - val_loss: 0.1881 - val_accuracy: 0.5899 - 3s/epoch - 81ms/step
# Epoch 53/10000
#
# Epoch 53: val_accuracy did not improve from 0.61297
# 37/37 - 3s - loss: 0.1070 - accuracy: 0.7600 - val_loss: 0.1874 - val_accuracy: 0.5794 - 3s/epoch - 81ms/step
# Epoch 54/10000
#
# Epoch 54: val_accuracy did not improve from 0.61297
# 37/37 - 3s - loss: 0.1057 - accuracy: 0.7604 - val_loss: 0.2090 - val_accuracy: 0.5558 - 3s/epoch - 81ms/step
# Epoch 55/10000
#
# Epoch 55: val_accuracy improved from 0.61297 to 0.63716, saving model to bestmodel.h5
# 37/37 - 4s - loss: 0.1041 - accuracy: 0.7666 - val_loss: 0.1608 - val_accuracy: 0.6372 - 4s/epoch - 100ms/step
# Epoch 56/10000
#
# Epoch 56: val_accuracy did not improve from 0.63716
# 37/37 - 4s - loss: 0.1038 - accuracy: 0.7701 - val_loss: 0.1874 - val_accuracy: 0.5635 - 4s/epoch - 112ms/step
# Epoch 57/10000
#
# Epoch 57: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.1027 - accuracy: 0.7556 - val_loss: 0.1835 - val_accuracy: 0.5959 - 3s/epoch - 83ms/step
# Epoch 58/10000
#
# Epoch 58: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.1025 - accuracy: 0.7747 - val_loss: 0.1732 - val_accuracy: 0.6240 - 3s/epoch - 83ms/step
# Epoch 59/10000
#
# Epoch 59: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.1010 - accuracy: 0.7688 - val_loss: 0.1714 - val_accuracy: 0.6322 - 3s/epoch - 82ms/step
# Epoch 60/10000
#
# Epoch 60: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.0996 - accuracy: 0.7758 - val_loss: 0.1814 - val_accuracy: 0.6157 - 3s/epoch - 82ms/step
# Epoch 61/10000
#
# Epoch 61: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.0997 - accuracy: 0.7794 - val_loss: 0.1734 - val_accuracy: 0.6146 - 3s/epoch - 82ms/step
# Epoch 62/10000
#
# Epoch 62: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.0989 - accuracy: 0.7814 - val_loss: 0.1743 - val_accuracy: 0.6190 - 3s/epoch - 82ms/step
# Epoch 63/10000
#
# Epoch 63: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.0964 - accuracy: 0.7897 - val_loss: 0.1847 - val_accuracy: 0.6036 - 3s/epoch - 81ms/step
# Epoch 64/10000
#
# Epoch 64: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.0982 - accuracy: 0.7825 - val_loss: 0.1962 - val_accuracy: 0.5739 - 3s/epoch - 80ms/step
# Epoch 65/10000
#
# Epoch 65: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.0961 - accuracy: 0.7908 - val_loss: 0.2063 - val_accuracy: 0.5651 - 3s/epoch - 83ms/step
# Epoch 66/10000
#
# Epoch 66: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.0963 - accuracy: 0.7916 - val_loss: 0.2076 - val_accuracy: 0.5800 - 3s/epoch - 82ms/step
# Epoch 67/10000
#
# Epoch 67: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.0962 - accuracy: 0.7890 - val_loss: 0.1761 - val_accuracy: 0.6174 - 3s/epoch - 83ms/step
# Epoch 68/10000
#
# Epoch 68: val_accuracy did not improve from 0.63716
# 37/37 - 3s - loss: 0.0958 - accuracy: 0.7942 - val_loss: 0.1818 - val_accuracy: 0.6256 - 3s/epoch - 84ms/step
# Epoch 69/10000
#
# Epoch 69: val_accuracy improved from 0.63716 to 0.67894, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.0960 - accuracy: 0.7969 - val_loss: 0.1538 - val_accuracy: 0.6789 - 3s/epoch - 84ms/step
# Epoch 70/10000
#
# Epoch 70: val_accuracy improved from 0.67894 to 0.70038, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.0927 - accuracy: 0.8059 - val_loss: 0.1510 - val_accuracy: 0.7004 - 3s/epoch - 84ms/step
# Epoch 71/10000
#
# Epoch 71: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0935 - accuracy: 0.7983 - val_loss: 0.1667 - val_accuracy: 0.6712 - 3s/epoch - 84ms/step
# Epoch 72/10000
#
# Epoch 72: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0927 - accuracy: 0.8118 - val_loss: 0.1687 - val_accuracy: 0.6493 - 3s/epoch - 85ms/step
# Epoch 73/10000
#
# Epoch 73: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0891 - accuracy: 0.8183 - val_loss: 0.2006 - val_accuracy: 0.6245 - 3s/epoch - 82ms/step
# Epoch 74/10000
#
# Epoch 74: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0918 - accuracy: 0.8085 - val_loss: 0.1720 - val_accuracy: 0.6603 - 3s/epoch - 82ms/step
# Epoch 75/10000
#
# Epoch 75: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0894 - accuracy: 0.8115 - val_loss: 0.1750 - val_accuracy: 0.6427 - 3s/epoch - 86ms/step
# Epoch 76/10000
#
# Epoch 76: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0883 - accuracy: 0.8217 - val_loss: 0.1743 - val_accuracy: 0.6520 - 3s/epoch - 82ms/step
# Epoch 77/10000
#
# Epoch 77: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0881 - accuracy: 0.8229 - val_loss: 0.1845 - val_accuracy: 0.6350 - 3s/epoch - 82ms/step
# Epoch 78/10000
#
# Epoch 78: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0871 - accuracy: 0.8200 - val_loss: 0.1601 - val_accuracy: 0.6833 - 3s/epoch - 83ms/step
# Epoch 79/10000
#
# Epoch 79: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0884 - accuracy: 0.8238 - val_loss: 0.1606 - val_accuracy: 0.6751 - 3s/epoch - 81ms/step
# Epoch 80/10000
#
# Epoch 80: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0873 - accuracy: 0.8199 - val_loss: 0.1657 - val_accuracy: 0.6729 - 3s/epoch - 82ms/step
# Epoch 81/10000
#
# Epoch 81: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0856 - accuracy: 0.8310 - val_loss: 0.1603 - val_accuracy: 0.6674 - 3s/epoch - 81ms/step
# Epoch 82/10000
#
# Epoch 82: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0848 - accuracy: 0.8315 - val_loss: 0.1565 - val_accuracy: 0.6734 - 3s/epoch - 82ms/step
# Epoch 83/10000
#
# Epoch 83: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0839 - accuracy: 0.8297 - val_loss: 0.1870 - val_accuracy: 0.6454 - 3s/epoch - 81ms/step
# Epoch 84/10000
#
# Epoch 84: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0828 - accuracy: 0.8320 - val_loss: 0.1869 - val_accuracy: 0.6306 - 3s/epoch - 81ms/step
# Epoch 85/10000
#
# Epoch 85: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0843 - accuracy: 0.8305 - val_loss: 0.1783 - val_accuracy: 0.6471 - 3s/epoch - 82ms/step
# Epoch 86/10000
#
# Epoch 86: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0819 - accuracy: 0.8323 - val_loss: 0.1602 - val_accuracy: 0.6817 - 3s/epoch - 81ms/step
# Epoch 87/10000
#
# Epoch 87: val_accuracy did not improve from 0.70038
# 37/37 - 3s - loss: 0.0816 - accuracy: 0.8370 - val_loss: 0.1604 - val_accuracy: 0.6789 - 3s/epoch - 81ms/step
# Epoch 88/10000
#
# Epoch 88: val_accuracy improved from 0.70038 to 0.70753, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.0799 - accuracy: 0.8383 - val_loss: 0.1477 - val_accuracy: 0.7075 - 3s/epoch - 84ms/step
# Epoch 89/10000
#
# Epoch 89: val_accuracy did not improve from 0.70753
# 37/37 - 3s - loss: 0.0814 - accuracy: 0.8317 - val_loss: 0.1595 - val_accuracy: 0.6976 - 3s/epoch - 82ms/step
# Epoch 90/10000
#
# Epoch 90: val_accuracy did not improve from 0.70753
# 37/37 - 3s - loss: 0.0825 - accuracy: 0.8305 - val_loss: 0.1742 - val_accuracy: 0.6734 - 3s/epoch - 82ms/step
# Epoch 91/10000
#
# Epoch 91: val_accuracy did not improve from 0.70753
# 37/37 - 3s - loss: 0.0788 - accuracy: 0.8438 - val_loss: 0.1845 - val_accuracy: 0.6690 - 3s/epoch - 85ms/step
# Epoch 92/10000
#
# Epoch 92: val_accuracy did not improve from 0.70753
# 37/37 - 3s - loss: 0.0762 - accuracy: 0.8449 - val_loss: 0.1689 - val_accuracy: 0.6718 - 3s/epoch - 84ms/step
# Epoch 93/10000
#
# Epoch 93: val_accuracy did not improve from 0.70753
# 37/37 - 3s - loss: 0.0800 - accuracy: 0.8335 - val_loss: 0.1778 - val_accuracy: 0.6647 - 3s/epoch - 81ms/step
# Epoch 94/10000
#
# Epoch 94: val_accuracy improved from 0.70753 to 0.71138, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.0791 - accuracy: 0.8412 - val_loss: 0.1496 - val_accuracy: 0.7114 - 3s/epoch - 83ms/step
# Epoch 95/10000
#
# Epoch 95: val_accuracy did not improve from 0.71138
# 37/37 - 3s - loss: 0.0807 - accuracy: 0.8372 - val_loss: 0.2083 - val_accuracy: 0.6223 - 3s/epoch - 82ms/step
# Epoch 96/10000
#
# Epoch 96: val_accuracy did not improve from 0.71138
# 37/37 - 3s - loss: 0.0794 - accuracy: 0.8381 - val_loss: 0.1602 - val_accuracy: 0.6943 - 3s/epoch - 84ms/step
# Epoch 97/10000
#
# Epoch 97: val_accuracy did not improve from 0.71138
# 37/37 - 3s - loss: 0.0781 - accuracy: 0.8440 - val_loss: 0.1754 - val_accuracy: 0.6679 - 3s/epoch - 81ms/step
# Epoch 98/10000
#
# Epoch 98: val_accuracy did not improve from 0.71138
# 37/37 - 3s - loss: 0.0780 - accuracy: 0.8407 - val_loss: 0.1715 - val_accuracy: 0.6685 - 3s/epoch - 81ms/step
# Epoch 99/10000
#
# Epoch 99: val_accuracy improved from 0.71138 to 0.71303, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.0760 - accuracy: 0.8491 - val_loss: 0.1508 - val_accuracy: 0.7130 - 3s/epoch - 83ms/step
# Epoch 100/10000
#
# Epoch 100: val_accuracy did not improve from 0.71303
# 37/37 - 3s - loss: 0.0777 - accuracy: 0.8437 - val_loss: 0.1590 - val_accuracy: 0.6916 - 3s/epoch - 81ms/step
# Epoch 101/10000
#
# Epoch 101: val_accuracy improved from 0.71303 to 0.72292, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.0769 - accuracy: 0.8466 - val_loss: 0.1435 - val_accuracy: 0.7229 - 3s/epoch - 84ms/step
# Epoch 102/10000
#
# Epoch 102: val_accuracy did not improve from 0.72292
# 37/37 - 3s - loss: 0.0749 - accuracy: 0.8504 - val_loss: 0.1613 - val_accuracy: 0.6943 - 3s/epoch - 83ms/step
# Epoch 103/10000
#
# Epoch 103: val_accuracy did not improve from 0.72292
# 37/37 - 3s - loss: 0.0744 - accuracy: 0.8513 - val_loss: 0.1551 - val_accuracy: 0.7092 - 3s/epoch - 81ms/step
# Epoch 104/10000
#
# Epoch 104: val_accuracy did not improve from 0.72292
# 37/37 - 3s - loss: 0.0749 - accuracy: 0.8499 - val_loss: 0.1928 - val_accuracy: 0.6443 - 3s/epoch - 82ms/step
# Epoch 105/10000
#
# Epoch 105: val_accuracy did not improve from 0.72292
# 37/37 - 4s - loss: 0.0742 - accuracy: 0.8510 - val_loss: 0.1730 - val_accuracy: 0.6822 - 4s/epoch - 96ms/step
# Epoch 106/10000
#
# Epoch 106: val_accuracy did not improve from 0.72292
# 37/37 - 3s - loss: 0.0753 - accuracy: 0.8517 - val_loss: 0.1544 - val_accuracy: 0.6943 - 3s/epoch - 89ms/step
# Epoch 107/10000
#
# Epoch 107: val_accuracy did not improve from 0.72292
# 37/37 - 3s - loss: 0.0760 - accuracy: 0.8442 - val_loss: 0.1504 - val_accuracy: 0.6888 - 3s/epoch - 82ms/step
# Epoch 108/10000
#
# Epoch 108: val_accuracy did not improve from 0.72292
# 37/37 - 3s - loss: 0.0744 - accuracy: 0.8552 - val_loss: 0.1599 - val_accuracy: 0.6855 - 3s/epoch - 81ms/step
# Epoch 109/10000
#
# Epoch 109: val_accuracy did not improve from 0.72292
# 37/37 - 3s - loss: 0.0746 - accuracy: 0.8555 - val_loss: 0.1407 - val_accuracy: 0.7191 - 3s/epoch - 82ms/step
# Epoch 110/10000
#
# Epoch 110: val_accuracy improved from 0.72292 to 0.72347, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.0735 - accuracy: 0.8565 - val_loss: 0.1446 - val_accuracy: 0.7235 - 3s/epoch - 82ms/step
# Epoch 111/10000
#
# Epoch 111: val_accuracy did not improve from 0.72347
# 37/37 - 3s - loss: 0.0736 - accuracy: 0.8554 - val_loss: 0.1596 - val_accuracy: 0.6883 - 3s/epoch - 82ms/step
# Epoch 112/10000
#
# Epoch 112: val_accuracy did not improve from 0.72347
# 37/37 - 3s - loss: 0.0717 - accuracy: 0.8603 - val_loss: 0.1691 - val_accuracy: 0.6729 - 3s/epoch - 82ms/step
# Epoch 113/10000
#
# Epoch 113: val_accuracy did not improve from 0.72347
# 37/37 - 3s - loss: 0.0714 - accuracy: 0.8598 - val_loss: 0.1613 - val_accuracy: 0.6899 - 3s/epoch - 81ms/step
# Epoch 114/10000
#
# Epoch 114: val_accuracy did not improve from 0.72347
# 37/37 - 3s - loss: 0.0723 - accuracy: 0.8572 - val_loss: 0.1959 - val_accuracy: 0.6498 - 3s/epoch - 81ms/step
# Epoch 115/10000
#
# Epoch 115: val_accuracy did not improve from 0.72347
# 37/37 - 3s - loss: 0.0729 - accuracy: 0.8507 - val_loss: 0.1778 - val_accuracy: 0.6839 - 3s/epoch - 81ms/step
# Epoch 116/10000
#
# Epoch 116: val_accuracy did not improve from 0.72347
# 37/37 - 3s - loss: 0.0729 - accuracy: 0.8514 - val_loss: 0.1778 - val_accuracy: 0.6773 - 3s/epoch - 82ms/step
# Epoch 117/10000
#
# Epoch 117: val_accuracy did not improve from 0.72347
# 37/37 - 3s - loss: 0.0716 - accuracy: 0.8592 - val_loss: 0.1792 - val_accuracy: 0.6822 - 3s/epoch - 81ms/step
# Epoch 118/10000
#
# Epoch 118: val_accuracy did not improve from 0.72347
# 37/37 - 3s - loss: 0.0718 - accuracy: 0.8580 - val_loss: 0.1591 - val_accuracy: 0.6905 - 3s/epoch - 81ms/step
# Epoch 119/10000
#
# Epoch 119: val_accuracy improved from 0.72347 to 0.73557, saving model to bestmodel.h5
# 37/37 - 3s - loss: 0.0728 - accuracy: 0.8554 - val_loss: 0.1371 - val_accuracy: 0.7356 - 3s/epoch - 83ms/step
# Epoch 120/10000
#
# Epoch 120: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0702 - accuracy: 0.8599 - val_loss: 0.1676 - val_accuracy: 0.6894 - 3s/epoch - 81ms/step
# Epoch 121/10000
#
# Epoch 121: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0709 - accuracy: 0.8609 - val_loss: 0.1786 - val_accuracy: 0.6614 - 3s/epoch - 81ms/step
# Epoch 122/10000
#
# Epoch 122: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0699 - accuracy: 0.8600 - val_loss: 0.1550 - val_accuracy: 0.7163 - 3s/epoch - 81ms/step
# Epoch 123/10000
#
# Epoch 123: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0716 - accuracy: 0.8535 - val_loss: 0.1391 - val_accuracy: 0.7317 - 3s/epoch - 81ms/step
# Epoch 124/10000
#
# Epoch 124: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0721 - accuracy: 0.8580 - val_loss: 0.1442 - val_accuracy: 0.7251 - 3s/epoch - 80ms/step
# Epoch 125/10000
#
# Epoch 125: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0698 - accuracy: 0.8655 - val_loss: 0.1512 - val_accuracy: 0.7092 - 3s/epoch - 80ms/step
# Epoch 126/10000
#
# Epoch 126: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0708 - accuracy: 0.8628 - val_loss: 0.1702 - val_accuracy: 0.6916 - 3s/epoch - 82ms/step
# Epoch 127/10000
#
# Epoch 127: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0685 - accuracy: 0.8664 - val_loss: 0.1737 - val_accuracy: 0.6844 - 3s/epoch - 81ms/step
# Epoch 128/10000
#
# Epoch 128: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0697 - accuracy: 0.8603 - val_loss: 0.1634 - val_accuracy: 0.7152 - 3s/epoch - 80ms/step
# Epoch 129/10000
#
# Epoch 129: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0710 - accuracy: 0.8591 - val_loss: 0.1462 - val_accuracy: 0.7213 - 3s/epoch - 80ms/step
# Epoch 130/10000
#
# Epoch 130: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0697 - accuracy: 0.8559 - val_loss: 0.1706 - val_accuracy: 0.6976 - 3s/epoch - 82ms/step
# Epoch 131/10000
#
# Epoch 131: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0675 - accuracy: 0.8644 - val_loss: 0.1677 - val_accuracy: 0.7059 - 3s/epoch - 80ms/step
# Epoch 132/10000
#
# Epoch 132: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0669 - accuracy: 0.8705 - val_loss: 0.1514 - val_accuracy: 0.7213 - 3s/epoch - 81ms/step
# Epoch 133/10000
#
# Epoch 133: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0697 - accuracy: 0.8636 - val_loss: 0.1512 - val_accuracy: 0.7158 - 3s/epoch - 87ms/step
# Epoch 134/10000
#
# Epoch 134: val_accuracy did not improve from 0.73557
# 37/37 - 5s - loss: 0.0683 - accuracy: 0.8651 - val_loss: 0.1410 - val_accuracy: 0.7339 - 5s/epoch - 123ms/step
# Epoch 135/10000
#
# Epoch 135: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0667 - accuracy: 0.8671 - val_loss: 0.1537 - val_accuracy: 0.7207 - 3s/epoch - 81ms/step
# Epoch 136/10000
#
# Epoch 136: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0678 - accuracy: 0.8662 - val_loss: 0.1772 - val_accuracy: 0.6745 - 3s/epoch - 82ms/step
# Epoch 137/10000
#
# Epoch 137: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0680 - accuracy: 0.8673 - val_loss: 0.1592 - val_accuracy: 0.7180 - 3s/epoch - 80ms/step
# Epoch 138/10000
#
# Epoch 138: val_accuracy did not improve from 0.73557
# 37/37 - 3s - loss: 0.0687 - accuracy: 0.8636 - val_loss: 0.1470 - val_accuracy: 0.7218 - 3s/epoch - 92ms/step
# Epoch 139/10000
#
# Epoch 139: val_accuracy did not improve from 0.73557
# Restoring model weights from the end of the best epoch: 119.
# 37/37 - 8s - loss: 0.0690 - accuracy: 0.8638 - val_loss: 0.1610 - val_accuracy: 0.7070 - 8s/epoch - 203ms/step
# Epoch 139: early stopping

# %%
# history contains the training information about accuracy and loss in every epoch
print(history.history.keys())

figure = plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model_EF.load_weights('bestmodel.h5')

y_predict = model_EF.predict(X_test)
acc_test = sum(y_test == np.argmax(y_predict, axis=1)) / y_test.shape[0]
y_test_cat = label2categorical(y_test,numClass)
# Convert back from categorical to numerical with np.argmax()
cm = skl.metrics.confusion_matrix(np.argmax(y_test_cat, axis=1), np.argmax(y_predict, axis=1))
print(cm)
plot_confusion_matrix(cm, np.unique(y_test).astype('int'))
# Out:
# [[105  91   0  43   0   0   1   2   0   1  11   0]
#  [  1  68 134   0   0   0   0   0   0   4  46   1]
#  [  0  38 164   0   0   0   0   0   1   0  51   0]
#  [  0   0   0  45   0   0 185   8   2   0  14   0]
#  [  0   0   0   0 239   0   0   3   1   1  10   0]
#  [  0   2   0   0   0 235   0   0   0   5  12   0]
#  [  0   0   0   3   0   0 200  13  12   2  23   1]
#  [  0   0   0   0   1   1   1 196   0  24  31   0]
#  [  0  10   0   4   0   0   2   1 209   3  25   0]
#  [  0   0   0   0   0   6   0   2   4 218  24   0]
#  [  0  14   1   0   0   0   0   0   0   0 239   0]
#  [  0   2   1  23   4   0 105  26  18   7  25  43]]

# %% [markdown]
# Now let's use the power of Functional API to build the Shared Filters Hybrid Fusion (SF-HF) method. But instead of using every single channel, I want to try using 3 channels at a time from every sensor, and then the shared filters should take an input of (200, 3).

# %%
shared_filters = keras.models.Sequential([
        layers.Reshape(target_shape=(200,3), input_shape=(200,3,1)),
        layers.Conv1D( filters = 10, kernel_size = 3, padding='same', activation='relu', input_shape=(200,3)),
        layers.MaxPooling1D(pool_size=(3)),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
        layers.Conv1D( filters = 20, kernel_size = 3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(pool_size=(3)),
        layers.Dropout(0.2),
        layers.Conv1D( filters = 40, kernel_size = 3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
        layers.Conv1D( filters = 80, kernel_size = 3, padding='same', activation='relu') #80
  ], name = 'shared_filters'
)

# we want to use this summary to see the output dimension of the shared filters
shared_filters.summary()
# Out:
# Model: "shared_filters"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 200, 3)            0
#
#  conv1d (Conv1D)             (None, 200, 10)           100
#
#  max_pooling1d (MaxPooling1D  (None, 66, 10)           0
#  )
#
#  batch_normalization (BatchN  (None, 66, 10)           40
#  ormalization)
#
#  dropout (Dropout)           (None, 66, 10)            0
#
#  conv1d_1 (Conv1D)           (None, 66, 20)            620
#
#  batch_normalization_1 (Batc  (None, 66, 20)           80
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 22, 20)           0
#  1D)
#
#  dropout_1 (Dropout)         (None, 22, 20)            0
#
#  conv1d_2 (Conv1D)           (None, 22, 40)            2440
#
#  batch_normalization_2 (Batc  (None, 22, 40)           160
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 22, 40)            0
#
#  conv1d_3 (Conv1D)           (None, 22, 80)            9680
#
# =================================================================
# Total params: 13,120
# Trainable params: 12,980
# Non-trainable params: 140
# _________________________________________________________________

# %% [markdown]
# To crop and select 3 channels at a time from the (200, 18) input, we can use the cropping2D layer:
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Cropping2D
#
# This is like pooling, it's rather an operation without any trainable parameters.

# %%
m_input_1 = layers.Input(shape=(200,18))
m_input_2 = layers.Reshape(target_shape=(200,18,1))(m_input_1)

m_sensor_0 = layers.Cropping2D(cropping=((0,0), (0, 15)))(m_input_2)
m_sensor_1 = layers.Cropping2D(cropping=((0,0), (3, 12)))(m_input_2)
m_sensor_2 = layers.Cropping2D(cropping=((0,0), (6, 9 )))(m_input_2)
m_sensor_3 = layers.Cropping2D(cropping=((0,0), (9, 6 )))(m_input_2)
m_sensor_4 = layers.Cropping2D(cropping=((0,0), (12,3 )))(m_input_2)
m_sensor_5 = layers.Cropping2D(cropping=((0,0), (15,0 )))(m_input_2)

m_sensor_0 = shared_filters(m_sensor_0)
m_sensor_1 = shared_filters(m_sensor_1)
m_sensor_2 = shared_filters(m_sensor_2)
m_sensor_3 = shared_filters(m_sensor_3)
m_sensor_4 = shared_filters(m_sensor_4)
m_sensor_5 = shared_filters(m_sensor_5)

m_output_1 = layers.Concatenate(axis=2)([m_sensor_0, m_sensor_1, m_sensor_2, m_sensor_3, m_sensor_4, m_sensor_5])

m_output_1 = layers.Conv1D(filters = 1, kernel_size = (3), padding='same', activation='relu')(m_output_1)
m_output_1 = layers.Flatten()(m_output_1)
m_output_1 = layers.Dense(20, activation='relu')(m_output_1)
m_output_1 = layers.Dense(numClass, activation='softmax')(m_output_1)

model_HF = keras.models.Model(inputs = m_input_1, outputs = m_output_1, name='model_HF')

# optimizer
m_opt = keras.optimizers.Adam(learning_rate=0.0001)
model_HF.compile(optimizer=m_opt,
                      loss=keras.losses.BinaryCrossentropy(),
                      metrics=['accuracy'])
model_HF.summary()
# Out:
# Model: "model_HF"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 18)]    0           []
#
#  reshape_1 (Reshape)            (None, 200, 18, 1)   0           ['input_1[0][0]']
#
#  cropping2d (Cropping2D)        (None, 200, 3, 1)    0           ['reshape_1[0][0]']
#
#  cropping2d_1 (Cropping2D)      (None, 200, 3, 1)    0           ['reshape_1[0][0]']
#
#  cropping2d_2 (Cropping2D)      (None, 200, 3, 1)    0           ['reshape_1[0][0]']
#
#  cropping2d_3 (Cropping2D)      (None, 200, 3, 1)    0           ['reshape_1[0][0]']
#
#  cropping2d_4 (Cropping2D)      (None, 200, 3, 1)    0           ['reshape_1[0][0]']
#
#  cropping2d_5 (Cropping2D)      (None, 200, 3, 1)    0           ['reshape_1[0][0]']
#
#  shared_filters (Sequential)    (None, 22, 80)       13120       ['cropping2d[0][0]',
#                                                                   'cropping2d_1[0][0]',
#                                                                   'cropping2d_2[0][0]',
#                                                                   'cropping2d_3[0][0]',
#                                                                   'cropping2d_4[0][0]',
#                                                                   'cropping2d_5[0][0]']
#
#  concatenate (Concatenate)      (None, 22, 480)      0           ['shared_filters[0][0]',
#                                                                   'shared_filters[1][0]',
#                                                                   'shared_filters[2][0]',
#                                                                   'shared_filters[3][0]',
#                                                                   'shared_filters[4][0]',
#                                                                   'shared_filters[5][0]']
#
#  conv1d_4 (Conv1D)              (None, 22, 1)        1441        ['concatenate[0][0]']
#
#  flatten (Flatten)              (None, 22)           0           ['conv1d_4[0][0]']
#
#  dense (Dense)                  (None, 20)           460         ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 12)           252         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 15,273
# Trainable params: 15,133
# Non-trainable params: 140
# __________________________________________________________________________________________________

# %% [markdown]
# First we see the total parameters are significantly less than EF. Also there's a new column: connected to, because of the sharing connections we made. There's an easier way to see it:

# %%
keras.utils.plot_model(model_HF, show_shapes=True)

# %%
# now let's train it, same process
epoch = 1000
batch = 200
cb_checkpoint = tf.keras.callbacks.ModelCheckpoint('bestmodel_HF.h5', monitor='val_accuracy', mode='max',
                                                   verbose=1,save_weights_only=False,save_best_only=True)
cb_earlystop = tf.keras.callbacks.EarlyStopping(patience=50,monitor='val_accuracy',mode='max',
                                                verbose=1,restore_best_weights=True)
history_2 = model_HF.fit( x = X_train, y = label2categorical(y_train, numClass), epochs = epoch, batch_size=batch,
                       validation_split=0.2, verbose = 2,
                       callbacks=[cb_checkpoint, cb_earlystop]
        )
# Out:
# Epoch 1/1000
#
# Epoch 1: val_accuracy improved from -inf to 0.07971, saving model to bestmodel_HF.h5
# 37/37 - 20s - loss: 0.6796 - accuracy: 0.0903 - val_loss: 0.6768 - val_accuracy: 0.0797 - 20s/epoch - 530ms/step
# Epoch 2/1000
#
# Epoch 2: val_accuracy did not improve from 0.07971
# 37/37 - 1s - loss: 0.6544 - accuracy: 0.0977 - val_loss: 0.6454 - val_accuracy: 0.0715 - 928ms/epoch - 25ms/step
# Epoch 3/1000
#
# Epoch 3: val_accuracy did not improve from 0.07971
# 37/37 - 1s - loss: 0.6125 - accuracy: 0.1075 - val_loss: 0.5928 - val_accuracy: 0.0599 - 863ms/epoch - 23ms/step
# Epoch 4/1000
#
# Epoch 4: val_accuracy did not improve from 0.07971
# 37/37 - 1s - loss: 0.5407 - accuracy: 0.1115 - val_loss: 0.5128 - val_accuracy: 0.0528 - 865ms/epoch - 23ms/step
# Epoch 5/1000
#
# Epoch 5: val_accuracy did not improve from 0.07971
# 37/37 - 1s - loss: 0.4470 - accuracy: 0.1152 - val_loss: 0.4227 - val_accuracy: 0.0627 - 846ms/epoch - 23ms/step
# Epoch 6/1000
#
# Epoch 6: val_accuracy improved from 0.07971 to 0.11325, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.3657 - accuracy: 0.1082 - val_loss: 0.3532 - val_accuracy: 0.1132 - 919ms/epoch - 25ms/step
# Epoch 7/1000
#
# Epoch 7: val_accuracy improved from 0.11325 to 0.11490, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.3176 - accuracy: 0.1105 - val_loss: 0.3221 - val_accuracy: 0.1149 - 933ms/epoch - 25ms/step
# Epoch 8/1000
#
# Epoch 8: val_accuracy improved from 0.11490 to 0.11655, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.2979 - accuracy: 0.1248 - val_loss: 0.3110 - val_accuracy: 0.1165 - 982ms/epoch - 27ms/step
# Epoch 9/1000
#
# Epoch 9: val_accuracy did not improve from 0.11655
# 37/37 - 1s - loss: 0.2894 - accuracy: 0.1586 - val_loss: 0.3060 - val_accuracy: 0.1111 - 883ms/epoch - 24ms/step
# Epoch 10/1000
#
# Epoch 10: val_accuracy did not improve from 0.11655
# 37/37 - 1s - loss: 0.2844 - accuracy: 0.1789 - val_loss: 0.3035 - val_accuracy: 0.1105 - 937ms/epoch - 25ms/step
# Epoch 11/1000
#
# Epoch 11: val_accuracy did not improve from 0.11655
# 37/37 - 1s - loss: 0.2802 - accuracy: 0.1984 - val_loss: 0.3022 - val_accuracy: 0.1045 - 872ms/epoch - 24ms/step
# Epoch 12/1000
#
# Epoch 12: val_accuracy did not improve from 0.11655
# 37/37 - 1s - loss: 0.2787 - accuracy: 0.2117 - val_loss: 0.3016 - val_accuracy: 0.0973 - 857ms/epoch - 23ms/step
# Epoch 13/1000
#
# Epoch 13: val_accuracy did not improve from 0.11655
# 37/37 - 1s - loss: 0.2756 - accuracy: 0.2206 - val_loss: 0.3011 - val_accuracy: 0.0968 - 865ms/epoch - 23ms/step
# Epoch 14/1000
#
# Epoch 14: val_accuracy did not improve from 0.11655
# 37/37 - 1s - loss: 0.2742 - accuracy: 0.2363 - val_loss: 0.3009 - val_accuracy: 0.0968 - 862ms/epoch - 23ms/step
# Epoch 15/1000
#
# Epoch 15: val_accuracy did not improve from 0.11655
# 37/37 - 1s - loss: 0.2716 - accuracy: 0.2490 - val_loss: 0.3005 - val_accuracy: 0.0973 - 866ms/epoch - 23ms/step
# Epoch 16/1000
#
# Epoch 16: val_accuracy did not improve from 0.11655
# 37/37 - 1s - loss: 0.2706 - accuracy: 0.2560 - val_loss: 0.3002 - val_accuracy: 0.1023 - 878ms/epoch - 24ms/step
# Epoch 17/1000
#
# Epoch 17: val_accuracy did not improve from 0.11655
# 37/37 - 1s - loss: 0.2681 - accuracy: 0.2732 - val_loss: 0.3000 - val_accuracy: 0.1012 - 960ms/epoch - 26ms/step
# Epoch 18/1000
#
# Epoch 18: val_accuracy did not improve from 0.11655
# 37/37 - 1s - loss: 0.2666 - accuracy: 0.2674 - val_loss: 0.3001 - val_accuracy: 0.1089 - 880ms/epoch - 24ms/step
# Epoch 19/1000
#
# Epoch 19: val_accuracy improved from 0.11655 to 0.13634, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.2650 - accuracy: 0.2792 - val_loss: 0.2999 - val_accuracy: 0.1363 - 925ms/epoch - 25ms/step
# Epoch 20/1000
#
# Epoch 20: val_accuracy improved from 0.13634 to 0.13744, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.2621 - accuracy: 0.2910 - val_loss: 0.2998 - val_accuracy: 0.1374 - 922ms/epoch - 25ms/step
# Epoch 21/1000
#
# Epoch 21: val_accuracy improved from 0.13744 to 0.14019, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.2596 - accuracy: 0.3051 - val_loss: 0.2999 - val_accuracy: 0.1402 - 926ms/epoch - 25ms/step
# Epoch 22/1000
#
# Epoch 22: val_accuracy did not improve from 0.14019
# 37/37 - 1s - loss: 0.2573 - accuracy: 0.3187 - val_loss: 0.3007 - val_accuracy: 0.1402 - 848ms/epoch - 23ms/step
# Epoch 23/1000
#
# Epoch 23: val_accuracy improved from 0.14019 to 0.14404, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.2562 - accuracy: 0.3085 - val_loss: 0.3002 - val_accuracy: 0.1440 - 919ms/epoch - 25ms/step
# Epoch 24/1000
#
# Epoch 24: val_accuracy did not improve from 0.14404
# 37/37 - 1s - loss: 0.2527 - accuracy: 0.3279 - val_loss: 0.3010 - val_accuracy: 0.1440 - 851ms/epoch - 23ms/step
# Epoch 25/1000
#
# Epoch 25: val_accuracy did not improve from 0.14404
# 37/37 - 1s - loss: 0.2504 - accuracy: 0.3346 - val_loss: 0.3013 - val_accuracy: 0.1424 - 871ms/epoch - 24ms/step
# Epoch 26/1000
#
# Epoch 26: val_accuracy improved from 0.14404 to 0.14458, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.2481 - accuracy: 0.3467 - val_loss: 0.3019 - val_accuracy: 0.1446 - 934ms/epoch - 25ms/step
# Epoch 27/1000
#
# Epoch 27: val_accuracy did not improve from 0.14458
# 37/37 - 1s - loss: 0.2452 - accuracy: 0.3581 - val_loss: 0.3023 - val_accuracy: 0.1418 - 881ms/epoch - 24ms/step
# Epoch 28/1000
#
# Epoch 28: val_accuracy did not improve from 0.14458
# 37/37 - 1s - loss: 0.2433 - accuracy: 0.3599 - val_loss: 0.3022 - val_accuracy: 0.1418 - 950ms/epoch - 26ms/step
# Epoch 29/1000
#
# Epoch 29: val_accuracy did not improve from 0.14458
# 37/37 - 1s - loss: 0.2407 - accuracy: 0.3686 - val_loss: 0.3031 - val_accuracy: 0.1424 - 871ms/epoch - 24ms/step
# Epoch 30/1000
#
# Epoch 30: val_accuracy improved from 0.14458 to 0.14513, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.2386 - accuracy: 0.3684 - val_loss: 0.3050 - val_accuracy: 0.1451 - 928ms/epoch - 25ms/step
# Epoch 31/1000
#
# Epoch 31: val_accuracy improved from 0.14513 to 0.14623, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.2363 - accuracy: 0.3856 - val_loss: 0.3062 - val_accuracy: 0.1462 - 914ms/epoch - 25ms/step
# Epoch 32/1000
#
# Epoch 32: val_accuracy improved from 0.14623 to 0.14678, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.2341 - accuracy: 0.3995 - val_loss: 0.3072 - val_accuracy: 0.1468 - 933ms/epoch - 25ms/step
# Epoch 33/1000
#
# Epoch 33: val_accuracy did not improve from 0.14678
# 37/37 - 1s - loss: 0.2322 - accuracy: 0.3935 - val_loss: 0.3067 - val_accuracy: 0.1468 - 1s/epoch - 35ms/step
# Epoch 34/1000
#
# Epoch 34: val_accuracy did not improve from 0.14678
# 37/37 - 1s - loss: 0.2300 - accuracy: 0.4027 - val_loss: 0.3078 - val_accuracy: 0.1462 - 865ms/epoch - 23ms/step
# Epoch 35/1000
#
# Epoch 35: val_accuracy improved from 0.14678 to 0.14733, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.2261 - accuracy: 0.4192 - val_loss: 0.3100 - val_accuracy: 0.1473 - 921ms/epoch - 25ms/step
# Epoch 36/1000
#
# Epoch 36: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2240 - accuracy: 0.4240 - val_loss: 0.3105 - val_accuracy: 0.1435 - 861ms/epoch - 23ms/step
# Epoch 37/1000
#
# Epoch 37: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2221 - accuracy: 0.4244 - val_loss: 0.3120 - val_accuracy: 0.1440 - 849ms/epoch - 23ms/step
# Epoch 38/1000
#
# Epoch 38: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2200 - accuracy: 0.4344 - val_loss: 0.3148 - val_accuracy: 0.1451 - 881ms/epoch - 24ms/step
# Epoch 39/1000
#
# Epoch 39: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2175 - accuracy: 0.4357 - val_loss: 0.3138 - val_accuracy: 0.1446 - 883ms/epoch - 24ms/step
# Epoch 40/1000
#
# Epoch 40: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2157 - accuracy: 0.4504 - val_loss: 0.3146 - val_accuracy: 0.1451 - 877ms/epoch - 24ms/step
# Epoch 41/1000
#
# Epoch 41: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2135 - accuracy: 0.4556 - val_loss: 0.3136 - val_accuracy: 0.1446 - 934ms/epoch - 25ms/step
# Epoch 42/1000
#
# Epoch 42: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2127 - accuracy: 0.4572 - val_loss: 0.3148 - val_accuracy: 0.1407 - 849ms/epoch - 23ms/step
# Epoch 43/1000
#
# Epoch 43: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2108 - accuracy: 0.4630 - val_loss: 0.3185 - val_accuracy: 0.1402 - 852ms/epoch - 23ms/step
# Epoch 44/1000
#
# Epoch 44: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2081 - accuracy: 0.4669 - val_loss: 0.3169 - val_accuracy: 0.1424 - 858ms/epoch - 23ms/step
# Epoch 45/1000
#
# Epoch 45: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2069 - accuracy: 0.4691 - val_loss: 0.3188 - val_accuracy: 0.1418 - 954ms/epoch - 26ms/step
# Epoch 46/1000
#
# Epoch 46: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2042 - accuracy: 0.4775 - val_loss: 0.3171 - val_accuracy: 0.1418 - 862ms/epoch - 23ms/step
# Epoch 47/1000
#
# Epoch 47: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2021 - accuracy: 0.4886 - val_loss: 0.3181 - val_accuracy: 0.1429 - 861ms/epoch - 23ms/step
# Epoch 48/1000
#
# Epoch 48: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.2012 - accuracy: 0.4929 - val_loss: 0.3220 - val_accuracy: 0.1413 - 933ms/epoch - 25ms/step
# Epoch 49/1000
#
# Epoch 49: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.1989 - accuracy: 0.4937 - val_loss: 0.3171 - val_accuracy: 0.1451 - 862ms/epoch - 23ms/step
# Epoch 50/1000
#
# Epoch 50: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.1963 - accuracy: 0.5115 - val_loss: 0.3186 - val_accuracy: 0.1451 - 867ms/epoch - 23ms/step
# Epoch 51/1000
#
# Epoch 51: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.1958 - accuracy: 0.5120 - val_loss: 0.3215 - val_accuracy: 0.1407 - 850ms/epoch - 23ms/step
# Epoch 52/1000
#
# Epoch 52: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.1943 - accuracy: 0.5192 - val_loss: 0.3205 - val_accuracy: 0.1424 - 862ms/epoch - 23ms/step
# Epoch 53/1000
#
# Epoch 53: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.1930 - accuracy: 0.5162 - val_loss: 0.3212 - val_accuracy: 0.1424 - 861ms/epoch - 23ms/step
# Epoch 54/1000
#
# Epoch 54: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.1913 - accuracy: 0.5231 - val_loss: 0.3215 - val_accuracy: 0.1424 - 866ms/epoch - 23ms/step
# Epoch 55/1000
#
# Epoch 55: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.1896 - accuracy: 0.5319 - val_loss: 0.3213 - val_accuracy: 0.1446 - 849ms/epoch - 23ms/step
# Epoch 56/1000
#
# Epoch 56: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.1885 - accuracy: 0.5316 - val_loss: 0.3211 - val_accuracy: 0.1446 - 855ms/epoch - 23ms/step
# Epoch 57/1000
#
# Epoch 57: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.1869 - accuracy: 0.5410 - val_loss: 0.3209 - val_accuracy: 0.1446 - 858ms/epoch - 23ms/step
# Epoch 58/1000
#
# Epoch 58: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.1851 - accuracy: 0.5425 - val_loss: 0.3227 - val_accuracy: 0.1435 - 934ms/epoch - 25ms/step
# Epoch 59/1000
#
# Epoch 59: val_accuracy did not improve from 0.14733
# 37/37 - 1s - loss: 0.1851 - accuracy: 0.5480 - val_loss: 0.3264 - val_accuracy: 0.1424 - 927ms/epoch - 25ms/step
# Epoch 60/1000
#
# Epoch 60: val_accuracy improved from 0.14733 to 0.15228, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1824 - accuracy: 0.5558 - val_loss: 0.3175 - val_accuracy: 0.1523 - 1s/epoch - 27ms/step
# Epoch 61/1000
#
# Epoch 61: val_accuracy did not improve from 0.15228
# 37/37 - 1s - loss: 0.1819 - accuracy: 0.5553 - val_loss: 0.3197 - val_accuracy: 0.1501 - 852ms/epoch - 23ms/step
# Epoch 62/1000
#
# Epoch 62: val_accuracy improved from 0.15228 to 0.15723, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1804 - accuracy: 0.5590 - val_loss: 0.3155 - val_accuracy: 0.1572 - 945ms/epoch - 26ms/step
# Epoch 63/1000
#
# Epoch 63: val_accuracy did not improve from 0.15723
# 37/37 - 1s - loss: 0.1791 - accuracy: 0.5659 - val_loss: 0.3161 - val_accuracy: 0.1556 - 856ms/epoch - 23ms/step
# Epoch 64/1000
#
# Epoch 64: val_accuracy improved from 0.15723 to 0.16877, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1783 - accuracy: 0.5773 - val_loss: 0.3114 - val_accuracy: 0.1688 - 934ms/epoch - 25ms/step
# Epoch 65/1000
#
# Epoch 65: val_accuracy did not improve from 0.16877
# 37/37 - 1s - loss: 0.1765 - accuracy: 0.5775 - val_loss: 0.3134 - val_accuracy: 0.1616 - 865ms/epoch - 23ms/step
# Epoch 66/1000
#
# Epoch 66: val_accuracy did not improve from 0.16877
# 37/37 - 1s - loss: 0.1746 - accuracy: 0.5917 - val_loss: 0.3117 - val_accuracy: 0.1688 - 848ms/epoch - 23ms/step
# Epoch 67/1000
#
# Epoch 67: val_accuracy improved from 0.16877 to 0.18032, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1750 - accuracy: 0.5861 - val_loss: 0.3072 - val_accuracy: 0.1803 - 1s/epoch - 27ms/step
# Epoch 68/1000
#
# Epoch 68: val_accuracy did not improve from 0.18032
# 37/37 - 1s - loss: 0.1727 - accuracy: 0.5962 - val_loss: 0.3104 - val_accuracy: 0.1737 - 892ms/epoch - 24ms/step
# Epoch 69/1000
#
# Epoch 69: val_accuracy improved from 0.18032 to 0.18362, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1717 - accuracy: 0.5983 - val_loss: 0.3084 - val_accuracy: 0.1836 - 914ms/epoch - 25ms/step
# Epoch 70/1000
#
# Epoch 70: val_accuracy did not improve from 0.18362
# 37/37 - 1s - loss: 0.1700 - accuracy: 0.6024 - val_loss: 0.3110 - val_accuracy: 0.1759 - 845ms/epoch - 23ms/step
# Epoch 71/1000
#
# Epoch 71: val_accuracy did not improve from 0.18362
# 37/37 - 1s - loss: 0.1684 - accuracy: 0.6156 - val_loss: 0.3108 - val_accuracy: 0.1820 - 858ms/epoch - 23ms/step
# Epoch 72/1000
#
# Epoch 72: val_accuracy improved from 0.18362 to 0.18966, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1674 - accuracy: 0.6115 - val_loss: 0.3049 - val_accuracy: 0.1897 - 937ms/epoch - 25ms/step
# Epoch 73/1000
#
# Epoch 73: val_accuracy did not improve from 0.18966
# 37/37 - 1s - loss: 0.1665 - accuracy: 0.6173 - val_loss: 0.3095 - val_accuracy: 0.1765 - 896ms/epoch - 24ms/step
# Epoch 74/1000
#
# Epoch 74: val_accuracy did not improve from 0.18966
# 37/37 - 1s - loss: 0.1659 - accuracy: 0.6195 - val_loss: 0.3077 - val_accuracy: 0.1809 - 936ms/epoch - 25ms/step
# Epoch 75/1000
#
# Epoch 75: val_accuracy did not improve from 0.18966
# 37/37 - 1s - loss: 0.1644 - accuracy: 0.6276 - val_loss: 0.3091 - val_accuracy: 0.1886 - 889ms/epoch - 24ms/step
# Epoch 76/1000
#
# Epoch 76: val_accuracy improved from 0.18966 to 0.19021, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1627 - accuracy: 0.6321 - val_loss: 0.3058 - val_accuracy: 0.1902 - 930ms/epoch - 25ms/step
# Epoch 77/1000
#
# Epoch 77: val_accuracy improved from 0.19021 to 0.19956, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1630 - accuracy: 0.6288 - val_loss: 0.2986 - val_accuracy: 0.1996 - 936ms/epoch - 25ms/step
# Epoch 78/1000
#
# Epoch 78: val_accuracy did not improve from 0.19956
# 37/37 - 1s - loss: 0.1604 - accuracy: 0.6362 - val_loss: 0.2998 - val_accuracy: 0.1979 - 878ms/epoch - 24ms/step
# Epoch 79/1000
#
# Epoch 79: val_accuracy improved from 0.19956 to 0.20946, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1599 - accuracy: 0.6450 - val_loss: 0.2949 - val_accuracy: 0.2095 - 929ms/epoch - 25ms/step
# Epoch 80/1000
#
# Epoch 80: val_accuracy did not improve from 0.20946
# 37/37 - 1s - loss: 0.1593 - accuracy: 0.6481 - val_loss: 0.2946 - val_accuracy: 0.2084 - 865ms/epoch - 23ms/step
# Epoch 81/1000
#
# Epoch 81: val_accuracy improved from 0.20946 to 0.21165, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1580 - accuracy: 0.6489 - val_loss: 0.2917 - val_accuracy: 0.2117 - 997ms/epoch - 27ms/step
# Epoch 82/1000
#
# Epoch 82: val_accuracy improved from 0.21165 to 0.21440, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1573 - accuracy: 0.6530 - val_loss: 0.2915 - val_accuracy: 0.2144 - 932ms/epoch - 25ms/step
# Epoch 83/1000
#
# Epoch 83: val_accuracy improved from 0.21440 to 0.21605, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1556 - accuracy: 0.6613 - val_loss: 0.2914 - val_accuracy: 0.2161 - 951ms/epoch - 26ms/step
# Epoch 84/1000
#
# Epoch 84: val_accuracy improved from 0.21605 to 0.22210, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1539 - accuracy: 0.6629 - val_loss: 0.2867 - val_accuracy: 0.2221 - 935ms/epoch - 25ms/step
# Epoch 85/1000
#
# Epoch 85: val_accuracy did not improve from 0.22210
# 37/37 - 1s - loss: 0.1538 - accuracy: 0.6650 - val_loss: 0.2873 - val_accuracy: 0.2199 - 961ms/epoch - 26ms/step
# Epoch 86/1000
#
# Epoch 86: val_accuracy improved from 0.22210 to 0.22870, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1517 - accuracy: 0.6706 - val_loss: 0.2835 - val_accuracy: 0.2287 - 951ms/epoch - 26ms/step
# Epoch 87/1000
#
# Epoch 87: val_accuracy improved from 0.22870 to 0.23035, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1512 - accuracy: 0.6729 - val_loss: 0.2812 - val_accuracy: 0.2303 - 935ms/epoch - 25ms/step
# Epoch 88/1000
#
# Epoch 88: val_accuracy improved from 0.23035 to 0.23364, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1503 - accuracy: 0.6745 - val_loss: 0.2788 - val_accuracy: 0.2336 - 915ms/epoch - 25ms/step
# Epoch 89/1000
#
# Epoch 89: val_accuracy did not improve from 0.23364
# 37/37 - 1s - loss: 0.1496 - accuracy: 0.6780 - val_loss: 0.2852 - val_accuracy: 0.2336 - 922ms/epoch - 25ms/step
# Epoch 90/1000
#
# Epoch 90: val_accuracy improved from 0.23364 to 0.23639, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1481 - accuracy: 0.6769 - val_loss: 0.2785 - val_accuracy: 0.2364 - 918ms/epoch - 25ms/step
# Epoch 91/1000
#
# Epoch 91: val_accuracy improved from 0.23639 to 0.24299, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1485 - accuracy: 0.6780 - val_loss: 0.2750 - val_accuracy: 0.2430 - 955ms/epoch - 26ms/step
# Epoch 92/1000
#
# Epoch 92: val_accuracy improved from 0.24299 to 0.24409, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1460 - accuracy: 0.6879 - val_loss: 0.2771 - val_accuracy: 0.2441 - 1s/epoch - 28ms/step
# Epoch 93/1000
#
# Epoch 93: val_accuracy improved from 0.24409 to 0.25344, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1459 - accuracy: 0.6835 - val_loss: 0.2716 - val_accuracy: 0.2534 - 935ms/epoch - 25ms/step
# Epoch 94/1000
#
# Epoch 94: val_accuracy improved from 0.25344 to 0.25454, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1449 - accuracy: 0.6907 - val_loss: 0.2737 - val_accuracy: 0.2545 - 1s/epoch - 27ms/step
# Epoch 95/1000
#
# Epoch 95: val_accuracy did not improve from 0.25454
# 37/37 - 1s - loss: 0.1433 - accuracy: 0.6927 - val_loss: 0.2795 - val_accuracy: 0.2545 - 881ms/epoch - 24ms/step
# Epoch 96/1000
#
# Epoch 96: val_accuracy did not improve from 0.25454
# 37/37 - 1s - loss: 0.1431 - accuracy: 0.6890 - val_loss: 0.2760 - val_accuracy: 0.2540 - 876ms/epoch - 24ms/step
# Epoch 97/1000
#
# Epoch 97: val_accuracy improved from 0.25454 to 0.26333, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1419 - accuracy: 0.7029 - val_loss: 0.2705 - val_accuracy: 0.2633 - 938ms/epoch - 25ms/step
# Epoch 98/1000
#
# Epoch 98: val_accuracy did not improve from 0.26333
# 37/37 - 1s - loss: 0.1409 - accuracy: 0.7042 - val_loss: 0.2752 - val_accuracy: 0.2567 - 865ms/epoch - 23ms/step
# Epoch 99/1000
#
# Epoch 99: val_accuracy improved from 0.26333 to 0.26388, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1401 - accuracy: 0.7015 - val_loss: 0.2729 - val_accuracy: 0.2639 - 926ms/epoch - 25ms/step
# Epoch 100/1000
#
# Epoch 100: val_accuracy improved from 0.26388 to 0.28367, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1406 - accuracy: 0.6984 - val_loss: 0.2639 - val_accuracy: 0.2837 - 1s/epoch - 27ms/step
# Epoch 101/1000
#
# Epoch 101: val_accuracy improved from 0.28367 to 0.29467, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1397 - accuracy: 0.7073 - val_loss: 0.2612 - val_accuracy: 0.2947 - 933ms/epoch - 25ms/step
# Epoch 102/1000
#
# Epoch 102: val_accuracy did not improve from 0.29467
# 37/37 - 1s - loss: 0.1385 - accuracy: 0.7131 - val_loss: 0.2648 - val_accuracy: 0.2892 - 863ms/epoch - 23ms/step
# Epoch 103/1000
#
# Epoch 103: val_accuracy improved from 0.29467 to 0.30456, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1380 - accuracy: 0.7083 - val_loss: 0.2605 - val_accuracy: 0.3046 - 927ms/epoch - 25ms/step
# Epoch 104/1000
#
# Epoch 104: val_accuracy improved from 0.30456 to 0.30621, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1363 - accuracy: 0.7145 - val_loss: 0.2615 - val_accuracy: 0.3062 - 937ms/epoch - 25ms/step
# Epoch 105/1000
#
# Epoch 105: val_accuracy improved from 0.30621 to 0.31226, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1361 - accuracy: 0.7149 - val_loss: 0.2598 - val_accuracy: 0.3123 - 961ms/epoch - 26ms/step
# Epoch 106/1000
#
# Epoch 106: val_accuracy did not improve from 0.31226
# 37/37 - 1s - loss: 0.1357 - accuracy: 0.7179 - val_loss: 0.2648 - val_accuracy: 0.2969 - 889ms/epoch - 24ms/step
# Epoch 107/1000
#
# Epoch 107: val_accuracy improved from 0.31226 to 0.31501, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1359 - accuracy: 0.7187 - val_loss: 0.2610 - val_accuracy: 0.3150 - 943ms/epoch - 25ms/step
# Epoch 108/1000
#
# Epoch 108: val_accuracy improved from 0.31501 to 0.32710, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1339 - accuracy: 0.7241 - val_loss: 0.2570 - val_accuracy: 0.3271 - 955ms/epoch - 26ms/step
# Epoch 109/1000
#
# Epoch 109: val_accuracy did not improve from 0.32710
# 37/37 - 1s - loss: 0.1338 - accuracy: 0.7235 - val_loss: 0.2566 - val_accuracy: 0.3216 - 866ms/epoch - 23ms/step
# Epoch 110/1000
#
# Epoch 110: val_accuracy improved from 0.32710 to 0.33865, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1335 - accuracy: 0.7206 - val_loss: 0.2532 - val_accuracy: 0.3386 - 934ms/epoch - 25ms/step
# Epoch 111/1000
#
# Epoch 111: val_accuracy improved from 0.33865 to 0.34195, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1332 - accuracy: 0.7222 - val_loss: 0.2502 - val_accuracy: 0.3419 - 914ms/epoch - 25ms/step
# Epoch 112/1000
#
# Epoch 112: val_accuracy did not improve from 0.34195
# 37/37 - 1s - loss: 0.1328 - accuracy: 0.7245 - val_loss: 0.2536 - val_accuracy: 0.3348 - 846ms/epoch - 23ms/step
# Epoch 113/1000
#
# Epoch 113: val_accuracy did not improve from 0.34195
# 37/37 - 1s - loss: 0.1314 - accuracy: 0.7338 - val_loss: 0.2509 - val_accuracy: 0.3414 - 917ms/epoch - 25ms/step
# Epoch 114/1000
#
# Epoch 114: val_accuracy improved from 0.34195 to 0.34799, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1307 - accuracy: 0.7327 - val_loss: 0.2485 - val_accuracy: 0.3480 - 1s/epoch - 27ms/step
# Epoch 115/1000
#
# Epoch 115: val_accuracy did not improve from 0.34799
# 37/37 - 1s - loss: 0.1299 - accuracy: 0.7348 - val_loss: 0.2536 - val_accuracy: 0.3419 - 926ms/epoch - 25ms/step
# Epoch 116/1000
#
# Epoch 116: val_accuracy did not improve from 0.34799
# 37/37 - 1s - loss: 0.1297 - accuracy: 0.7369 - val_loss: 0.2526 - val_accuracy: 0.3480 - 878ms/epoch - 24ms/step
# Epoch 117/1000
#
# Epoch 117: val_accuracy improved from 0.34799 to 0.35734, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1293 - accuracy: 0.7355 - val_loss: 0.2506 - val_accuracy: 0.3573 - 935ms/epoch - 25ms/step
# Epoch 118/1000
#
# Epoch 118: val_accuracy improved from 0.35734 to 0.35899, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1278 - accuracy: 0.7432 - val_loss: 0.2460 - val_accuracy: 0.3590 - 924ms/epoch - 25ms/step
# Epoch 119/1000
#
# Epoch 119: val_accuracy improved from 0.35899 to 0.36229, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1283 - accuracy: 0.7385 - val_loss: 0.2447 - val_accuracy: 0.3623 - 1s/epoch - 27ms/step
# Epoch 120/1000
#
# Epoch 120: val_accuracy did not improve from 0.36229
# 37/37 - 1s - loss: 0.1281 - accuracy: 0.7381 - val_loss: 0.2506 - val_accuracy: 0.3546 - 950ms/epoch - 26ms/step
# Epoch 121/1000
#
# Epoch 121: val_accuracy improved from 0.36229 to 0.36778, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1264 - accuracy: 0.7424 - val_loss: 0.2443 - val_accuracy: 0.3678 - 937ms/epoch - 25ms/step
# Epoch 122/1000
#
# Epoch 122: val_accuracy did not improve from 0.36778
# 37/37 - 1s - loss: 0.1258 - accuracy: 0.7464 - val_loss: 0.2406 - val_accuracy: 0.3672 - 863ms/epoch - 23ms/step
# Epoch 123/1000
#
# Epoch 123: val_accuracy improved from 0.36778 to 0.36833, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1255 - accuracy: 0.7513 - val_loss: 0.2439 - val_accuracy: 0.3683 - 1s/epoch - 27ms/step
# Epoch 124/1000
#
# Epoch 124: val_accuracy improved from 0.36833 to 0.37658, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1237 - accuracy: 0.7523 - val_loss: 0.2409 - val_accuracy: 0.3766 - 923ms/epoch - 25ms/step
# Epoch 125/1000
#
# Epoch 125: val_accuracy did not improve from 0.37658
# 37/37 - 1s - loss: 0.1241 - accuracy: 0.7550 - val_loss: 0.2380 - val_accuracy: 0.3755 - 851ms/epoch - 23ms/step
# Epoch 126/1000
#
# Epoch 126: val_accuracy did not improve from 0.37658
# 37/37 - 1s - loss: 0.1242 - accuracy: 0.7508 - val_loss: 0.2441 - val_accuracy: 0.3744 - 832ms/epoch - 22ms/step
# Epoch 127/1000
#
# Epoch 127: val_accuracy did not improve from 0.37658
# 37/37 - 1s - loss: 0.1235 - accuracy: 0.7542 - val_loss: 0.2440 - val_accuracy: 0.3755 - 858ms/epoch - 23ms/step
# Epoch 128/1000
#
# Epoch 128: val_accuracy did not improve from 0.37658
# 37/37 - 1s - loss: 0.1229 - accuracy: 0.7591 - val_loss: 0.2403 - val_accuracy: 0.3766 - 865ms/epoch - 23ms/step
# Epoch 129/1000
#
# Epoch 129: val_accuracy did not improve from 0.37658
# 37/37 - 1s - loss: 0.1223 - accuracy: 0.7622 - val_loss: 0.2439 - val_accuracy: 0.3766 - 980ms/epoch - 26ms/step
# Epoch 130/1000
#
# Epoch 130: val_accuracy improved from 0.37658 to 0.37768, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1214 - accuracy: 0.7596 - val_loss: 0.2435 - val_accuracy: 0.3777 - 919ms/epoch - 25ms/step
# Epoch 131/1000
#
# Epoch 131: val_accuracy did not improve from 0.37768
# 37/37 - 1s - loss: 0.1215 - accuracy: 0.7600 - val_loss: 0.2391 - val_accuracy: 0.3738 - 863ms/epoch - 23ms/step
# Epoch 132/1000
#
# Epoch 132: val_accuracy improved from 0.37768 to 0.37988, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1210 - accuracy: 0.7633 - val_loss: 0.2366 - val_accuracy: 0.3799 - 918ms/epoch - 25ms/step
# Epoch 133/1000
#
# Epoch 133: val_accuracy did not improve from 0.37988
# 37/37 - 1s - loss: 0.1205 - accuracy: 0.7604 - val_loss: 0.2409 - val_accuracy: 0.3755 - 859ms/epoch - 23ms/step
# Epoch 134/1000
#
# Epoch 134: val_accuracy did not improve from 0.37988
# 37/37 - 1s - loss: 0.1189 - accuracy: 0.7689 - val_loss: 0.2389 - val_accuracy: 0.3766 - 872ms/epoch - 24ms/step
# Epoch 135/1000
#
# Epoch 135: val_accuracy did not improve from 0.37988
# 37/37 - 1s - loss: 0.1196 - accuracy: 0.7678 - val_loss: 0.2448 - val_accuracy: 0.3727 - 844ms/epoch - 23ms/step
# Epoch 136/1000
#
# Epoch 136: val_accuracy did not improve from 0.37988
# 37/37 - 1s - loss: 0.1187 - accuracy: 0.7684 - val_loss: 0.2391 - val_accuracy: 0.3771 - 853ms/epoch - 23ms/step
# Epoch 137/1000
#
# Epoch 137: val_accuracy did not improve from 0.37988
# 37/37 - 1s - loss: 0.1188 - accuracy: 0.7689 - val_loss: 0.2371 - val_accuracy: 0.3755 - 858ms/epoch - 23ms/step
# Epoch 138/1000
#
# Epoch 138: val_accuracy improved from 0.37988 to 0.38098, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1182 - accuracy: 0.7686 - val_loss: 0.2396 - val_accuracy: 0.3810 - 1000ms/epoch - 27ms/step
# Epoch 139/1000
#
# Epoch 139: val_accuracy improved from 0.38098 to 0.38208, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1178 - accuracy: 0.7736 - val_loss: 0.2423 - val_accuracy: 0.3821 - 931ms/epoch - 25ms/step
# Epoch 140/1000
#
# Epoch 140: val_accuracy improved from 0.38208 to 0.38318, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1180 - accuracy: 0.7682 - val_loss: 0.2367 - val_accuracy: 0.3832 - 937ms/epoch - 25ms/step
# Epoch 141/1000
#
# Epoch 141: val_accuracy did not improve from 0.38318
# 37/37 - 1s - loss: 0.1175 - accuracy: 0.7747 - val_loss: 0.2378 - val_accuracy: 0.3771 - 872ms/epoch - 24ms/step
# Epoch 142/1000
#
# Epoch 142: val_accuracy improved from 0.38318 to 0.38538, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1164 - accuracy: 0.7748 - val_loss: 0.2380 - val_accuracy: 0.3854 - 936ms/epoch - 25ms/step
# Epoch 143/1000
#
# Epoch 143: val_accuracy improved from 0.38538 to 0.38868, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1159 - accuracy: 0.7752 - val_loss: 0.2355 - val_accuracy: 0.3887 - 940ms/epoch - 25ms/step
# Epoch 144/1000
#
# Epoch 144: val_accuracy did not improve from 0.38868
# 37/37 - 1s - loss: 0.1158 - accuracy: 0.7777 - val_loss: 0.2386 - val_accuracy: 0.3788 - 874ms/epoch - 24ms/step
# Epoch 145/1000
#
# Epoch 145: val_accuracy did not improve from 0.38868
# 37/37 - 1s - loss: 0.1151 - accuracy: 0.7833 - val_loss: 0.2359 - val_accuracy: 0.3887 - 863ms/epoch - 23ms/step
# Epoch 146/1000
#
# Epoch 146: val_accuracy did not improve from 0.38868
# 37/37 - 1s - loss: 0.1145 - accuracy: 0.7829 - val_loss: 0.2388 - val_accuracy: 0.3826 - 862ms/epoch - 23ms/step
# Epoch 147/1000
#
# Epoch 147: val_accuracy improved from 0.38868 to 0.39252, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1140 - accuracy: 0.7816 - val_loss: 0.2367 - val_accuracy: 0.3925 - 907ms/epoch - 25ms/step
# Epoch 148/1000
#
# Epoch 148: val_accuracy did not improve from 0.39252
# 37/37 - 1s - loss: 0.1146 - accuracy: 0.7832 - val_loss: 0.2373 - val_accuracy: 0.3914 - 862ms/epoch - 23ms/step
# Epoch 149/1000
#
# Epoch 149: val_accuracy did not improve from 0.39252
# 37/37 - 1s - loss: 0.1141 - accuracy: 0.7805 - val_loss: 0.2370 - val_accuracy: 0.3876 - 876ms/epoch - 24ms/step
# Epoch 150/1000
#
# Epoch 150: val_accuracy did not improve from 0.39252
# 37/37 - 1s - loss: 0.1131 - accuracy: 0.7825 - val_loss: 0.2367 - val_accuracy: 0.3909 - 859ms/epoch - 23ms/step
# Epoch 151/1000
#
# Epoch 151: val_accuracy did not improve from 0.39252
# 37/37 - 1s - loss: 0.1131 - accuracy: 0.7876 - val_loss: 0.2361 - val_accuracy: 0.3870 - 856ms/epoch - 23ms/step
# Epoch 152/1000
#
# Epoch 152: val_accuracy improved from 0.39252 to 0.39307, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1116 - accuracy: 0.7861 - val_loss: 0.2327 - val_accuracy: 0.3931 - 963ms/epoch - 26ms/step
# Epoch 153/1000
#
# Epoch 153: val_accuracy did not improve from 0.39307
# 37/37 - 1s - loss: 0.1118 - accuracy: 0.7932 - val_loss: 0.2352 - val_accuracy: 0.3892 - 862ms/epoch - 23ms/step
# Epoch 154/1000
#
# Epoch 154: val_accuracy did not improve from 0.39307
# 37/37 - 1s - loss: 0.1108 - accuracy: 0.7898 - val_loss: 0.2362 - val_accuracy: 0.3843 - 867ms/epoch - 23ms/step
# Epoch 155/1000
#
# Epoch 155: val_accuracy did not improve from 0.39307
# 37/37 - 1s - loss: 0.1107 - accuracy: 0.7921 - val_loss: 0.2368 - val_accuracy: 0.3909 - 833ms/epoch - 23ms/step
# Epoch 156/1000
#
# Epoch 156: val_accuracy improved from 0.39307 to 0.39362, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1105 - accuracy: 0.7919 - val_loss: 0.2375 - val_accuracy: 0.3936 - 937ms/epoch - 25ms/step
# Epoch 157/1000
#
# Epoch 157: val_accuracy did not improve from 0.39362
# 37/37 - 1s - loss: 0.1104 - accuracy: 0.7965 - val_loss: 0.2347 - val_accuracy: 0.3909 - 872ms/epoch - 24ms/step
# Epoch 158/1000
#
# Epoch 158: val_accuracy did not improve from 0.39362
# 37/37 - 1s - loss: 0.1101 - accuracy: 0.7935 - val_loss: 0.2351 - val_accuracy: 0.3914 - 938ms/epoch - 25ms/step
# Epoch 159/1000
#
# Epoch 159: val_accuracy did not improve from 0.39362
# 37/37 - 1s - loss: 0.1088 - accuracy: 0.7968 - val_loss: 0.2333 - val_accuracy: 0.3876 - 847ms/epoch - 23ms/step
# Epoch 160/1000
#
# Epoch 160: val_accuracy did not improve from 0.39362
# 37/37 - 1s - loss: 0.1092 - accuracy: 0.7923 - val_loss: 0.2352 - val_accuracy: 0.3898 - 868ms/epoch - 23ms/step
# Epoch 161/1000
#
# Epoch 161: val_accuracy improved from 0.39362 to 0.39802, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1079 - accuracy: 0.7985 - val_loss: 0.2324 - val_accuracy: 0.3980 - 929ms/epoch - 25ms/step
# Epoch 162/1000
#
# Epoch 162: val_accuracy did not improve from 0.39802
# 37/37 - 1s - loss: 0.1078 - accuracy: 0.7997 - val_loss: 0.2317 - val_accuracy: 0.3980 - 870ms/epoch - 24ms/step
# Epoch 163/1000
#
# Epoch 163: val_accuracy did not improve from 0.39802
# 37/37 - 1s - loss: 0.1073 - accuracy: 0.8015 - val_loss: 0.2358 - val_accuracy: 0.3931 - 859ms/epoch - 23ms/step
# Epoch 164/1000
#
# Epoch 164: val_accuracy did not improve from 0.39802
# 37/37 - 1s - loss: 0.1064 - accuracy: 0.7994 - val_loss: 0.2354 - val_accuracy: 0.3936 - 862ms/epoch - 23ms/step
# Epoch 165/1000
#
# Epoch 165: val_accuracy did not improve from 0.39802
# 37/37 - 1s - loss: 0.1068 - accuracy: 0.8004 - val_loss: 0.2350 - val_accuracy: 0.3953 - 850ms/epoch - 23ms/step
# Epoch 166/1000
#
# Epoch 166: val_accuracy did not improve from 0.39802
# 37/37 - 1s - loss: 0.1060 - accuracy: 0.8071 - val_loss: 0.2371 - val_accuracy: 0.3975 - 858ms/epoch - 23ms/step
# Epoch 167/1000
#
# Epoch 167: val_accuracy did not improve from 0.39802
# 37/37 - 1s - loss: 0.1067 - accuracy: 0.8018 - val_loss: 0.2342 - val_accuracy: 0.3980 - 844ms/epoch - 23ms/step
# Epoch 168/1000
#
# Epoch 168: val_accuracy improved from 0.39802 to 0.40132, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1047 - accuracy: 0.8045 - val_loss: 0.2346 - val_accuracy: 0.4013 - 930ms/epoch - 25ms/step
# Epoch 169/1000
#
# Epoch 169: val_accuracy did not improve from 0.40132
# 37/37 - 1s - loss: 0.1058 - accuracy: 0.8038 - val_loss: 0.2371 - val_accuracy: 0.3953 - 854ms/epoch - 23ms/step
# Epoch 170/1000
#
# Epoch 170: val_accuracy did not improve from 0.40132
# 37/37 - 1s - loss: 0.1051 - accuracy: 0.8041 - val_loss: 0.2357 - val_accuracy: 0.3975 - 857ms/epoch - 23ms/step
# Epoch 171/1000
#
# Epoch 171: val_accuracy did not improve from 0.40132
# 37/37 - 1s - loss: 0.1035 - accuracy: 0.8088 - val_loss: 0.2351 - val_accuracy: 0.3953 - 852ms/epoch - 23ms/step
# Epoch 172/1000
#
# Epoch 172: val_accuracy did not improve from 0.40132
# 37/37 - 1s - loss: 0.1050 - accuracy: 0.8062 - val_loss: 0.2377 - val_accuracy: 0.4008 - 860ms/epoch - 23ms/step
# Epoch 173/1000
#
# Epoch 173: val_accuracy improved from 0.40132 to 0.40462, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1047 - accuracy: 0.8024 - val_loss: 0.2347 - val_accuracy: 0.4046 - 1s/epoch - 27ms/step
# Epoch 174/1000
#
# Epoch 174: val_accuracy did not improve from 0.40462
# 37/37 - 1s - loss: 0.1039 - accuracy: 0.8026 - val_loss: 0.2368 - val_accuracy: 0.3964 - 851ms/epoch - 23ms/step
# Epoch 175/1000
#
# Epoch 175: val_accuracy did not improve from 0.40462
# 37/37 - 1s - loss: 0.1038 - accuracy: 0.8053 - val_loss: 0.2392 - val_accuracy: 0.3832 - 857ms/epoch - 23ms/step
# Epoch 176/1000
#
# Epoch 176: val_accuracy did not improve from 0.40462
# 37/37 - 1s - loss: 0.1032 - accuracy: 0.8114 - val_loss: 0.2363 - val_accuracy: 0.3914 - 868ms/epoch - 23ms/step
# Epoch 177/1000
#
# Epoch 177: val_accuracy did not improve from 0.40462
# 37/37 - 1s - loss: 0.1040 - accuracy: 0.8099 - val_loss: 0.2364 - val_accuracy: 0.3947 - 850ms/epoch - 23ms/step
# Epoch 178/1000
#
# Epoch 178: val_accuracy did not improve from 0.40462
# 37/37 - 1s - loss: 0.1028 - accuracy: 0.8103 - val_loss: 0.2363 - val_accuracy: 0.3870 - 869ms/epoch - 23ms/step
# Epoch 179/1000
#
# Epoch 179: val_accuracy did not improve from 0.40462
# 37/37 - 1s - loss: 0.1034 - accuracy: 0.8104 - val_loss: 0.2353 - val_accuracy: 0.3942 - 835ms/epoch - 23ms/step
# Epoch 180/1000
#
# Epoch 180: val_accuracy did not improve from 0.40462
# 37/37 - 1s - loss: 0.1006 - accuracy: 0.8143 - val_loss: 0.2379 - val_accuracy: 0.4013 - 857ms/epoch - 23ms/step
# Epoch 181/1000
#
# Epoch 181: val_accuracy did not improve from 0.40462
# 37/37 - 1s - loss: 0.1018 - accuracy: 0.8110 - val_loss: 0.2377 - val_accuracy: 0.3975 - 844ms/epoch - 23ms/step
# Epoch 182/1000
#
# Epoch 182: val_accuracy did not improve from 0.40462
# 37/37 - 1s - loss: 0.1011 - accuracy: 0.8176 - val_loss: 0.2394 - val_accuracy: 0.3892 - 851ms/epoch - 23ms/step
# Epoch 183/1000
#
# Epoch 183: val_accuracy did not improve from 0.40462
# 37/37 - 1s - loss: 0.1020 - accuracy: 0.8110 - val_loss: 0.2387 - val_accuracy: 0.3925 - 868ms/epoch - 23ms/step
# Epoch 184/1000
#
# Epoch 184: val_accuracy improved from 0.40462 to 0.40572, saving model to bestmodel_HF.h5
# 37/37 - 1s - loss: 0.1002 - accuracy: 0.8172 - val_loss: 0.2377 - val_accuracy: 0.4057 - 927ms/epoch - 25ms/step
# Epoch 185/1000
#
# Epoch 185: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0994 - accuracy: 0.8199 - val_loss: 0.2399 - val_accuracy: 0.3991 - 883ms/epoch - 24ms/step
# Epoch 186/1000
#
# Epoch 186: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.1003 - accuracy: 0.8203 - val_loss: 0.2405 - val_accuracy: 0.3936 - 875ms/epoch - 24ms/step
# Epoch 187/1000
#
# Epoch 187: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0999 - accuracy: 0.8159 - val_loss: 0.2395 - val_accuracy: 0.3903 - 877ms/epoch - 24ms/step
# Epoch 188/1000
#
# Epoch 188: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0995 - accuracy: 0.8191 - val_loss: 0.2405 - val_accuracy: 0.3865 - 888ms/epoch - 24ms/step
# Epoch 189/1000
#
# Epoch 189: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0991 - accuracy: 0.8173 - val_loss: 0.2395 - val_accuracy: 0.3936 - 890ms/epoch - 24ms/step
# Epoch 190/1000
#
# Epoch 190: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0978 - accuracy: 0.8184 - val_loss: 0.2395 - val_accuracy: 0.3881 - 966ms/epoch - 26ms/step
# Epoch 191/1000
#
# Epoch 191: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0983 - accuracy: 0.8214 - val_loss: 0.2404 - val_accuracy: 0.3870 - 858ms/epoch - 23ms/step
# Epoch 192/1000
#
# Epoch 192: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0978 - accuracy: 0.8214 - val_loss: 0.2403 - val_accuracy: 0.3931 - 896ms/epoch - 24ms/step
# Epoch 193/1000
#
# Epoch 193: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0979 - accuracy: 0.8213 - val_loss: 0.2395 - val_accuracy: 0.3876 - 874ms/epoch - 24ms/step
# Epoch 194/1000
#
# Epoch 194: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0985 - accuracy: 0.8209 - val_loss: 0.2404 - val_accuracy: 0.3887 - 864ms/epoch - 23ms/step
# Epoch 195/1000
#
# Epoch 195: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0977 - accuracy: 0.8251 - val_loss: 0.2393 - val_accuracy: 0.3892 - 893ms/epoch - 24ms/step
# Epoch 196/1000
#
# Epoch 196: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0975 - accuracy: 0.8232 - val_loss: 0.2402 - val_accuracy: 0.3887 - 853ms/epoch - 23ms/step
# Epoch 197/1000
#
# Epoch 197: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0960 - accuracy: 0.8280 - val_loss: 0.2393 - val_accuracy: 0.3914 - 875ms/epoch - 24ms/step
# Epoch 198/1000
#
# Epoch 198: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0960 - accuracy: 0.8265 - val_loss: 0.2385 - val_accuracy: 0.3898 - 865ms/epoch - 23ms/step
# Epoch 199/1000
#
# Epoch 199: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0954 - accuracy: 0.8301 - val_loss: 0.2387 - val_accuracy: 0.3848 - 862ms/epoch - 23ms/step
# Epoch 200/1000
#
# Epoch 200: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0959 - accuracy: 0.8268 - val_loss: 0.2387 - val_accuracy: 0.3936 - 894ms/epoch - 24ms/step
# Epoch 201/1000
#
# Epoch 201: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0948 - accuracy: 0.8308 - val_loss: 0.2414 - val_accuracy: 0.3793 - 856ms/epoch - 23ms/step
# Epoch 202/1000
#
# Epoch 202: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0941 - accuracy: 0.8301 - val_loss: 0.2400 - val_accuracy: 0.3859 - 859ms/epoch - 23ms/step
# Epoch 203/1000
#
# Epoch 203: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0945 - accuracy: 0.8268 - val_loss: 0.2383 - val_accuracy: 0.3942 - 943ms/epoch - 25ms/step
# Epoch 204/1000
#
# Epoch 204: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0949 - accuracy: 0.8308 - val_loss: 0.2398 - val_accuracy: 0.3854 - 851ms/epoch - 23ms/step
# Epoch 205/1000
#
# Epoch 205: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0944 - accuracy: 0.8339 - val_loss: 0.2383 - val_accuracy: 0.3859 - 935ms/epoch - 25ms/step
# Epoch 206/1000
#
# Epoch 206: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0945 - accuracy: 0.8246 - val_loss: 0.2419 - val_accuracy: 0.3821 - 961ms/epoch - 26ms/step
# Epoch 207/1000
#
# Epoch 207: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0941 - accuracy: 0.8286 - val_loss: 0.2398 - val_accuracy: 0.3821 - 866ms/epoch - 23ms/step
# Epoch 208/1000
#
# Epoch 208: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0937 - accuracy: 0.8313 - val_loss: 0.2428 - val_accuracy: 0.3821 - 868ms/epoch - 23ms/step
# Epoch 209/1000
#
# Epoch 209: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0930 - accuracy: 0.8321 - val_loss: 0.2421 - val_accuracy: 0.3848 - 880ms/epoch - 24ms/step
# Epoch 210/1000
#
# Epoch 210: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0925 - accuracy: 0.8283 - val_loss: 0.2408 - val_accuracy: 0.3815 - 868ms/epoch - 23ms/step
# Epoch 211/1000
#
# Epoch 211: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0924 - accuracy: 0.8339 - val_loss: 0.2401 - val_accuracy: 0.3810 - 876ms/epoch - 24ms/step
# Epoch 212/1000
#
# Epoch 212: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0925 - accuracy: 0.8331 - val_loss: 0.2381 - val_accuracy: 0.3909 - 876ms/epoch - 24ms/step
# Epoch 213/1000
#
# Epoch 213: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0922 - accuracy: 0.8334 - val_loss: 0.2424 - val_accuracy: 0.3815 - 873ms/epoch - 24ms/step
# Epoch 214/1000
#
# Epoch 214: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0922 - accuracy: 0.8348 - val_loss: 0.2413 - val_accuracy: 0.3815 - 866ms/epoch - 23ms/step
# Epoch 215/1000
#
# Epoch 215: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0911 - accuracy: 0.8389 - val_loss: 0.2416 - val_accuracy: 0.3799 - 867ms/epoch - 23ms/step
# Epoch 216/1000
#
# Epoch 216: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0926 - accuracy: 0.8350 - val_loss: 0.2432 - val_accuracy: 0.3815 - 864ms/epoch - 23ms/step
# Epoch 217/1000
#
# Epoch 217: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0917 - accuracy: 0.8316 - val_loss: 0.2395 - val_accuracy: 0.3881 - 893ms/epoch - 24ms/step
# Epoch 218/1000
#
# Epoch 218: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0911 - accuracy: 0.8350 - val_loss: 0.2422 - val_accuracy: 0.3777 - 868ms/epoch - 23ms/step
# Epoch 219/1000
#
# Epoch 219: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0901 - accuracy: 0.8409 - val_loss: 0.2449 - val_accuracy: 0.3760 - 865ms/epoch - 23ms/step
# Epoch 220/1000
#
# Epoch 220: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0891 - accuracy: 0.8397 - val_loss: 0.2427 - val_accuracy: 0.3815 - 879ms/epoch - 24ms/step
# Epoch 221/1000
#
# Epoch 221: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0881 - accuracy: 0.8415 - val_loss: 0.2412 - val_accuracy: 0.3832 - 883ms/epoch - 24ms/step
# Epoch 222/1000
#
# Epoch 222: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0906 - accuracy: 0.8363 - val_loss: 0.2410 - val_accuracy: 0.3821 - 884ms/epoch - 24ms/step
# Epoch 223/1000
#
# Epoch 223: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0914 - accuracy: 0.8280 - val_loss: 0.2471 - val_accuracy: 0.3727 - 862ms/epoch - 23ms/step
# Epoch 224/1000
#
# Epoch 224: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0911 - accuracy: 0.8372 - val_loss: 0.2435 - val_accuracy: 0.3766 - 922ms/epoch - 25ms/step
# Epoch 225/1000
#
# Epoch 225: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0884 - accuracy: 0.8408 - val_loss: 0.2451 - val_accuracy: 0.3744 - 855ms/epoch - 23ms/step
# Epoch 226/1000
#
# Epoch 226: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0891 - accuracy: 0.8409 - val_loss: 0.2440 - val_accuracy: 0.3766 - 873ms/epoch - 24ms/step
# Epoch 227/1000
#
# Epoch 227: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0889 - accuracy: 0.8431 - val_loss: 0.2445 - val_accuracy: 0.3694 - 861ms/epoch - 23ms/step
# Epoch 228/1000
#
# Epoch 228: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0881 - accuracy: 0.8434 - val_loss: 0.2440 - val_accuracy: 0.3744 - 886ms/epoch - 24ms/step
# Epoch 229/1000
#
# Epoch 229: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0879 - accuracy: 0.8400 - val_loss: 0.2447 - val_accuracy: 0.3749 - 869ms/epoch - 23ms/step
# Epoch 230/1000
#
# Epoch 230: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0877 - accuracy: 0.8420 - val_loss: 0.2443 - val_accuracy: 0.3755 - 852ms/epoch - 23ms/step
# Epoch 231/1000
#
# Epoch 231: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0878 - accuracy: 0.8420 - val_loss: 0.2469 - val_accuracy: 0.3766 - 866ms/epoch - 23ms/step
# Epoch 232/1000
#
# Epoch 232: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0877 - accuracy: 0.8372 - val_loss: 0.2430 - val_accuracy: 0.3711 - 845ms/epoch - 23ms/step
# Epoch 233/1000
#
# Epoch 233: val_accuracy did not improve from 0.40572
# 37/37 - 1s - loss: 0.0873 - accuracy: 0.8419 - val_loss: 0.2498 - val_accuracy: 0.3694 - 863ms/epoch - 23ms/step
# Epoch 234/1000
#
# Epoch 234: val_accuracy did not improve from 0.40572
# Restoring model weights from the end of the best epoch: 184.
# 37/37 - 1s - loss: 0.0875 - accuracy: 0.8434 - val_loss: 0.2485 - val_accuracy: 0.3711 - 863ms/epoch - 23ms/step
# Epoch 234: early stopping

# %% [markdown]
# You might notice that this smaller model on the contary takes extremely longer time to train per epoch compared with the bigger EF model. This is because the operation of activating the shared filters 6 times is not effectively paralizable. But we can optimize this for example defining 6x shared filters instances and lock their weights together, but this is out of this project scope

# %%
y_predict = model_HF.predict(X_test)
acc_test = sum(y_test == np.argmax(y_predict, axis=1)) / y_test.shape[0]
y_test_cat = label2categorical(y_test,numClass)
# Convert back from categorical to numerical with np.argmax()
cm = skl.metrics.confusion_matrix(np.argmax(y_test_cat, axis=1), np.argmax(y_predict, axis=1))
print(cm)
plot_confusion_matrix(cm, np.unique(y_test).astype('int'))
# Out:
# [[228   8   0   0   0   0   0   6  11   1   0   0]
#  [  1 117   1   0   0   0   0  59  73   1   2   0]
#  [  1 113  82   0   0   0   0  55   3   0   0   0]
#  [  0  14   0  22   0   0  22 164  32   0   0   0]
#  [  0  17   0   0 102   0  23   1 111   0   0   0]
#  [ 13   8   0   0   0  20   0   0 200   1  12   0]
#  [  0  23   0   0   0   0  82  17 132   0   0   0]
#  [  0  28   1   0   0   0   8 200  17   0   0   0]
#  [  2  32   0   2   0   0  19 172  27   0   0   0]
#  [  7   8   0   0   0   2   1  18  51  85  82   0]
#  [  0  65   0   0   0   0   0   0 189   0   0   0]
#  [  0  17   0   0  82   2   8   0 140   0   0   5]]

# %% [markdown]
# # Epilogue
#
# In this part, we've explored the sensor fusion with some quite advanced deep learning techniques. Curiously for my own attempt the SF-HF approach (albeit my customized version) hasn't outperformed the EF approach. This might just be we haven't trained the model enough, or some details in the shared filters need improving.
